# %% [markdown]
# # Load Data

# %%
import kagglehub
import os
import shutil
import pandas as pd
import re
from string import punctuation

# %%
# Path dataset cache Kaggle (sudah disediakan otomatis)
cached_path = "/kaggle/input/englishrussian-dictionary-for-machine-translate"
target_dir = "/content/englishrussian-dictionary"

# Jika dataset belum tersedia di cache, baru unduh
if not os.path.exists(cached_path):
    print("Downloading dataset via kagglehub...")
    path = kagglehub.dataset_download("hijest/englishrussian-dictionary-for-machine-translate")
    print("Downloaded and cached at:", path)
else:
    print("Dataset already available at:", cached_path)
    path = cached_path

# Salin dataset ke /content agar bisa dimodifikasi (karena /kaggle/input bersifat read-only)
if not os.path.exists(target_dir):
    shutil.copytree(path, target_dir)

print("Dataset copied to working directory:", target_dir)
# Out:
# Downloading dataset via kagglehub...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/hijest/englishrussian-dictionary-for-machine-translate?dataset_version_number=1...
# 100%|██████████| 11.9M/11.9M [00:02<00:00, 5.51MB/s]
# Extracting files...
# Downloaded and cached at: /root/.cache/kagglehub/datasets/hijest/englishrussian-dictionary-for-machine-translate/versions/1
# Dataset copied to working directory: /content/englishrussian-dictionary

# %%
data=pd.read_csv('../content/englishrussian-dictionary/rus.txt',delimiter='\t',header=None)

# %%
data.head()
# Out:
#      0              1                                                  2
# 0  Go.          Марш!  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1  Go.           Иди.  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 2  Go.         Идите.  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 3  Hi.  Здравствуйте.  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 4  Hi.        Привет!  CC-BY 2.0 (France) Attribution: tatoeba.org #5...

# %%
data=data.iloc[:,:2]

# %%
data.head()
# Out:
#      0              1
# 0  Go.          Марш!
# 1  Go.           Иди.
# 2  Go.         Идите.
# 3  Hi.  Здравствуйте.
# 4  Hi.        Привет!

# %%
data.rename(columns={0: "English", 1: "Russian"},inplace=True)

# %%
data.columns
# Out:
# Index(['English', 'Russian'], dtype='object')

# %% [markdown]
# ## Text Preprocessing - Data Preparation
#
# ### Fungsi `clean_string()`
# Fungsi ini melakukan pembersihan teks dengan beberapa langkah:
# 1. **Normalisasi karakter khusus**: Mengganti no-break space (`\u202f`) dengan spasi biasa
# 2. **Konversi ke huruf kecil**: Semua karakter diubah menjadi lowercase untuk konsistensi
# 3. **Penghapusan tanda baca dan angka**: Menghilangkan karakter punctuation, guillemets (« »), dan digit (0-9)
# 4. **Penghapusan spasi ganda**: Menggunakan regex untuk mengganti multiple whitespace menjadi single space
# 5. **Trimming**: Menghapus spasi di awal dan akhir string
#
# ### Penerapan Preprocessing
# Setelah fungsi dibuat, preprocessing diterapkan pada dataset:
# - Kolom `English` dan `Russian` dikonversi ke tipe string
# - Fungsi `clean_string()` diaplikasikan ke setiap baris menggunakan `apply()` dan lambda function
# - Hasilnya adalah teks yang bersih, uniform, dan siap untuk tokenisasi

# %%
# Clean the string
def clean_string(string):
    # Replace no-break space with space
    string = string.replace("\u202f"," ")
    # Converts all uppercase characters into lowercase characters
    string = string.lower()

    # Delete the punctuation and the numbers
    for p in punctuation + "«»" + "0123456789":
        string = string.replace(p," ")

    # Eliminate duplicate whitespaces using wildcards
    string = re.sub("\s+"," ", string)
    # Remove spaces at the beginning and at the end of the string
    string = string.strip()

    return string
#-------------------------------------------------------------------------------
# object to string
data['English'] = data['English'].astype(str)
data['Russian'] = data['Russian'].astype(str)

# Clean the sentences
data['English'] = data['English'].apply(lambda x: clean_string(x))
data['Russian'] = data['Russian'].apply(lambda x: clean_string(x))

data.tail()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1097322099.py:13: SyntaxWarning: invalid escape sequence '\s'
#   string = re.sub("\s+"," ", string)
#                                                   English  \
# 363381  in today s world we have to equip all our kids...
# 363382  death is something that we re often discourage...
# 363383  at a moment when our economy is growing our bu...
# 363384  since there are usually multiple websites on a...
# 363385  doubtless there exists in this world precisely...
#
#                                                   Russian
# 363381  в современном мире перед нами стоит задача дат...
# 363382  смерть это зачастую то разговоры или даже мысл...
# 363383  в тот момент когда наша экономика растёт наши ...
# 363384  поскольку сайтов посвящённых какой либо теме к...
# 363385  несомненно для каждого мужчины в этом мире где...

# %%
# === Simpan dataset hasil cleaning ke CSV ===
save_path = "/content/englishrussian-dictionary/eng_rus_cleaned.csv"
data.to_csv(save_path, index=False)
print(f"Cleaned dataset saved to: {save_path}")
print(data.head())

# === Konfigurasi dasar ===
import torch
import random
import numpy as np

DATA_PATH = save_path
SRC_COL = "English"
TGT_COL = "Russian"

BATCH_SIZE = 100  # maksimal sesuai instruksi
NUM_EPOCHS = 1    # hanya 1 epoch
LR = 1e-4
EMB_SIZE = 128
NHEAD = 4
FFN_HID_DIM = 256
NUM_ENCODER_LAYERS = 1
NUM_DECODER_LAYERS = 1
DROPOUT = 0.1
MAX_LEN = 100
MIN_FREQ = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
SAVE_MODEL = False
MODEL_SAVE_PATH = "transformer_eng_ru.pt"

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

print("Device in use:", DEVICE)
# Out:
# Cleaned dataset saved to: /content/englishrussian-dictionary/eng_rus_cleaned.csv
#   English       Russian
# 0      go          марш
# 1      go           иди
# 2      go         идите
# 3      hi  здравствуйте
# 4      hi        привет
# Device in use: cuda

# %% [markdown]
# ## Tokenisasi dan Vocabulary Building
#
# Setelah pembersihan data, tahap selanjutnya adalah mempersiapkan sistem tokenisasi dan vocabulary untuk mengubah teks menjadi representasi numerik.
#
# ### Fungsi `normalize_text()` dan `tokenize()`
# - **`normalize_text()`**: Melakukan normalisasi tingkat lanjut dengan:
#   - Konversi ke lowercase dan trimming
#   - Penghapusan multiple whitespace
#   - Pemisahan tanda baca dengan spasi (contoh: "hello!" → "hello !")
#
# - **`tokenize()`**: Fungsi sederhana untuk memecah teks menjadi token berdasarkan spasi setelah dinormalisasi
#
# ### Class `Vocab`
# Class ini bertanggung jawab untuk membangun dan mengelola vocabulary:
#
# **Atribut utama:**
# - `itos` (int-to-string): List yang memetakan index ke token
# - `stoi` (string-to-int): Dictionary yang memetakan token ke index
# - `freqs`: Dictionary untuk menghitung frekuensi kemunculan setiap token
# - `min_freq`: Threshold minimum frekuensi agar token dimasukkan ke vocabulary
#
# **Special tokens:**
# - `<pad>`: Padding token untuk menyamakan panjang sequence
# - `<sos>`: Start-of-sequence token
# - `<eos>`: End-of-sequence token
# - `<unk>`: Unknown token untuk kata yang tidak ada di vocabulary
#
# **Method penting:**
# - `add_sentence()`: Menambahkan token dari kalimat dan menghitung frekuensinya
# - `build()`: Membangun vocabulary final dengan filter berdasarkan `min_freq`
# - `tokens_to_ids()`: Konversi token menjadi ID numerik
# - `ids_to_tokens()`: Konversi ID numerik kembali menjadi token
#
# Vocabulary dibangun untuk source (English) dan target (Russian) secara terpisah karena keduanya memiliki kosakata yang berbeda.

# %%
# -----------------------------
# Tokenisasi dan Normalisasi
# -----------------------------
import re
from typing import List

def normalize_text(s: str) -> str:
    """Normalisasi dasar untuk teks (huruf kecil, buang spasi ganda, pisahkan tanda baca)."""
    s = s.lower().strip()
    s = re.sub(r"\s+", " ", s)
    s = re.sub(r"([.,!?;:()\"«»-])", r" \1 ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def tokenize(s: str) -> List[str]:
    """Tokenisasi sederhana berbasis spasi."""
    s = normalize_text(s)
    return s.split()


# -----------------------------
# Vocabulary Builder
# -----------------------------
class Vocab:
    def __init__(self, min_freq=1, specials=["<pad>", "<sos>", "<eos>", "<unk>"]):
        self.min_freq = min_freq
        self.itos = list(specials)
        self.stoi = {tok: i for i, tok in enumerate(self.itos)}
        self.freqs = {}

    def add_sentence(self, tokens: List[str]):
        for t in tokens:
            self.freqs[t] = self.freqs.get(t, 0) + 1

    def build(self):
        items = [(tok, cnt) for tok, cnt in self.freqs.items() if cnt >= self.min_freq]
        items.sort(key=lambda x: (-x[1], x[0]))  # sort by frequency desc
        for tok, _ in items:
            if tok not in self.stoi:
                self.stoi[tok] = len(self.itos)
                self.itos.append(tok)

    def __len__(self):
        return len(self.itos)

    def tokens_to_ids(self, tokens: List[str]) -> List[int]:
        """Ubah daftar token menjadi daftar ID."""
        return [self.stoi.get(t, self.stoi["<unk>"]) for t in tokens]

    def ids_to_tokens(self, ids: List[int]) -> List[str]:
        """Ubah daftar ID menjadi token kembali."""
        return [self.itos[i] if i < len(self.itos) else "<unk>" for i in ids]

# %%
# Bangun vocabulary dari dataset
src_vocab = Vocab(min_freq=MIN_FREQ)
tgt_vocab = Vocab(min_freq=MIN_FREQ)

for s in data[SRC_COL]:
    src_vocab.add_sentence(tokenize(s)[:MAX_LEN])

for t in data[TGT_COL]:
    tgt_vocab.add_sentence(tokenize(t)[:(MAX_LEN - 2)])  # -2 untuk <sos> & <eos>

src_vocab.build()
tgt_vocab.build()

print(f"Source vocab size (English): {len(src_vocab)}")
print(f"Target vocab size (Russian): {len(tgt_vocab)}")
# Out:
# Source vocab size (English): 11338
# Target vocab size (Russian): 31619

# %% [markdown]
# ## Dataset dan DataLoader Preparation
#
# Tahap ini mempersiapkan data agar dapat dibatch dan diproses efisien oleh model.
#
# ### Class `TranslationDataset`
# Custom PyTorch Dataset untuk pasangan kalimat translation (English → Russian):
# - Menyimpan pasangan teks source dan target
# - Menyimpan referensi ke vocabulary untuk konversi token-ID
# - Membatasi panjang maksimum sequence untuk efisiensi
# - Method `__getitem__()` mengembalikan token (bukan ID) untuk fleksibilitas preprocessing di collate function
#
# ### Fungsi `collate_fn()`
# Fungsi ini sangat krusial untuk batch processing:
#
# **Proses yang dilakukan:**
# 1. **Menentukan panjang maksimum** dalam batch untuk source dan target
# 2. **Konversi token ke ID** menggunakan vocabulary
# 3. **Penambahan special tokens**:
#    - Target input: Menambahkan `<sos>` di awal
#    - Target output: Menambahkan `<eos>` di akhir
# 4. **Padding**: Menambahkan `<pad>` token hingga semua sequence dalam batch memiliki panjang sama
# 5. **Transpose**: Mengubah shape dari `(batch, seq_len)` menjadi `(seq_len, batch)` sesuai format PyTorch Transformer
# 6. **Padding mask**: Membuat boolean mask untuk menandai posisi padding (True = padding, False = token aktual)
#
# ### Data Splitting
# Data dibagi menjadi:
# - **Train**: 80% untuk training model
# - **Validation**: 10% untuk monitoring performance selama training
# - **Test**: 10% untuk evaluasi akhir
#
# DataLoader dibuat dengan batch size dan shuffle sesuai kebutuhan training.

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# -----------------------------
# Dataset Class
# -----------------------------
class TranslationDataset(Dataset):
    """Dataset untuk pasangan kalimat English → Russian."""
    def __init__(self, src_texts, tgt_texts, src_vocab, tgt_vocab, max_len=MAX_LEN):
        assert len(src_texts) == len(tgt_texts)
        self.src_texts = src_texts
        self.tgt_texts = tgt_texts
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.max_len = max_len

    def __len__(self):
        return len(self.src_texts)

    def __getitem__(self, idx):
        src_tokens = tokenize(self.src_texts[idx])[:self.max_len]
        tgt_tokens = tokenize(self.tgt_texts[idx])[:(self.max_len - 2)]  # reserve for <sos>/<eos>
        return src_tokens, tgt_tokens


# -----------------------------
# Fungsi Collate untuk batching
# -----------------------------
def collate_fn(batch, src_vocab, tgt_vocab):
    """Menyiapkan batch data agar cocok untuk nn.Transformer."""
    pad_id = src_vocab.stoi["<pad>"]
    sos_id = tgt_vocab.stoi["<sos>"]
    eos_id = tgt_vocab.stoi["<eos>"]

    src_seqs, tgt_in_seqs, tgt_out_seqs = [], [], []

    max_src_len = max(len(s[0]) for s in batch)
    max_tgt_len = max(len(s[1]) for s in batch) + 2  # tambah 2 utk <sos> dan <eos>

    for src_tokens, tgt_tokens in batch:
        # Source
        src_ids = src_vocab.tokens_to_ids(src_tokens)
        src_padded = src_ids + [pad_id] * (max_src_len - len(src_ids))
        src_seqs.append(src_padded)

        # Target
        tgt_ids = tgt_vocab.tokens_to_ids(tgt_tokens)
        tgt_input = [sos_id] + tgt_ids + [pad_id] * (max_tgt_len - len(tgt_ids) - 1)
        tgt_output = tgt_ids + [eos_id] + [pad_id] * (max_tgt_len - len(tgt_ids) - 1)

        tgt_in_seqs.append(tgt_input)
        tgt_out_seqs.append(tgt_output)

    # Convert ke tensor (seq_len, batch_size)
    src_tensor = torch.LongTensor(src_seqs).transpose(0, 1)
    tgt_in_tensor = torch.LongTensor(tgt_in_seqs).transpose(0, 1)
    tgt_out_tensor = torch.LongTensor(tgt_out_seqs).transpose(0, 1)

    # Padding mask: True di posisi <pad>
    src_pad_mask = (src_tensor.transpose(0, 1) == pad_id)
    tgt_pad_mask = (tgt_in_tensor.transpose(0, 1) == pad_id)

    return src_tensor, tgt_in_tensor, tgt_out_tensor, src_pad_mask, tgt_pad_mask

# %%
import random

# Shuffle dan split dataset
pairs = list(zip(data[SRC_COL].tolist(), data[TGT_COL].tolist()))
random.shuffle(pairs)

train_split = int(0.8 * len(pairs))
val_split = int(0.1 * len(pairs))

train_data = pairs[:train_split]
val_data = pairs[train_split:train_split + val_split]
test_data = pairs[train_split + val_split:]

train_src, train_tgt = zip(*train_data)
val_src, val_tgt = zip(*val_data)
test_src, test_tgt = zip(*test_data)

# Buat dataset
train_dataset = TranslationDataset(train_src, train_tgt, src_vocab, tgt_vocab)
val_dataset = TranslationDataset(val_src, val_tgt, src_vocab, tgt_vocab)
test_dataset = TranslationDataset(test_src, test_tgt, src_vocab, tgt_vocab)

# Buat DataLoader
collate = lambda batch: collate_fn(batch, src_vocab, tgt_vocab)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate)

print(f"Train batches: {len(train_loader)} | Val batches: {len(val_loader)} | Test batches: {len(test_loader)}")
# Out:
# Train batches: 2908 | Val batches: 364 | Test batches: 364

# %% [markdown]
# ## Arsitektur Transformer - Definisi Class
#
# ### Class `PositionalEncoding`
#
# Positional Encoding menambahkan informasi posisi ke dalam token embeddings karena Transformer tidak memiliki mekanisme urutan bawaan seperti RNN/LSTM.
#
# **Implementasi:**
# - Menggunakan sinusoidal functions (sin dan cos) seperti pada paper "Attention is All You Need"
# - Formula:
#   - PE(pos, 2i) = sin(pos / 10000^(2i/d_model))
#   - PE(pos, 2i+1) = cos(pos / 10000^(2i/d_model))
# - Positional encoding ditambahkan langsung ke embedding dengan operasi penjumlahan
# - Menggunakan `register_buffer()` agar tensor tidak dianggap sebagai parameter yang perlu di-train
# - Mendukung embedding size ganjil dan genap
#
# **Input/Output:**
# - Input: `(seq_len, batch, emb_size)`
# - Output: sama dengan input, dengan positional information terintegrasi
#
# ---
#
# ### Class `TransformerModel`
#
# Class utama yang merangkum seluruh arsitektur Transformer untuk task machine translation.
#
# **Komponen utama:**
#
# 1. **Token Embeddings:**
#    - `src_tok_emb`: Embedding layer untuk source language (English)
#    - `tgt_tok_emb`: Embedding layer untuk target language (Russian)
#    - Embedding di-scale dengan √(emb_size) untuk stabilitas training
#
# 2. **Positional Encoding:**
#    - Instance dari `PositionalEncoding` class
#    - Diterapkan setelah embedding untuk menambahkan informasi posisi
#
# 3. **Transformer Core:**
#    - Menggunakan `nn.Transformer` dari PyTorch
#    - Konfigurasi:
#      - `d_model`: Dimensi embedding (EMB_SIZE = 128)
#      - `nhead`: Jumlah attention heads (NHEAD = 4)
#      - `num_encoder_layers`: Jumlah layer encoder (1)
#      - `num_decoder_layers`: Jumlah layer decoder (1)
#      - `dim_feedforward`: Dimensi hidden layer FFN (FFN_HID_DIM = 256)
#      - `dropout`: Dropout rate untuk regularisasi (0.1)
#      - `batch_first=False`: Format input (seq_len, batch, emb_size)
#
# 4. **Generator (Output Layer):**
#    - Linear layer yang memetakan output decoder ke vocabulary size
#    - Output: logits untuk setiap token di vocabulary target
#
# **Method penting:**
#
# - **`forward()`**: Full forward pass untuk training
#   - Input: source sequence, target input sequence, masks
#   - Process: embedding → positional encoding → transformer → generator
#   - Output: logits dengan shape (T, N, V_tgt)
#
# - **`encode()`**: Hanya menjalankan encoder
#   - Digunakan saat inference untuk encode source sentence sekali
#   - Return: memory (encoded representation)
#
# - **`decode()`**: Hanya menjalankan decoder
#   - Digunakan saat inference untuk generate token secara iteratif
#   - Input: target sequence (yang sudah digenerate), memory dari encoder
#
# **Inisialisasi parameter:**
# - Menggunakan Xavier uniform initialization untuk stabilitas training
# - Diterapkan ke semua parameter dengan dimensi > 1

# %%
# -----------------------------
# Positional Encoding + Transformer model
# -----------------------------
import math
import torch.nn as nn

class PositionalEncoding(nn.Module):
    """
    Sinusoidal positional encoding (same style as "Attention is All You Need").
    Adds positional information to token embeddings.
    """
    def __init__(self, emb_size: int, maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(maxlen, emb_size)
        position = torch.arange(0, maxlen, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, emb_size, 2).float() * (-math.log(10000.0) / emb_size))
        pe[:, 0::2] = torch.sin(position * div_term)
        if emb_size % 2 == 1:
            # handle odd embedding sizes
            pe[:, 1::2] = torch.cos(position * div_term[:-1])
        else:
            pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(1)  # (maxlen, 1, emb_size)
        self.register_buffer("pe", pe)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: (seq_len, batch, emb_size)
        returns: same shape with positional encodings added
        """
        return x + self.pe[:x.size(0)].to(x.device)


class TransformerModel(nn.Module):
    """
    Simple wrapper around torch.nn.Transformer with learned token embeddings
    and a final linear generator to predict target token logits.
    """
    def __init__(
        self,
        src_vocab_size: int,
        tgt_vocab_size: int,
        emb_size: int = EMB_SIZE,
        nhead: int = NHEAD,
        num_encoder_layers: int = NUM_ENCODER_LAYERS,
        num_decoder_layers: int = NUM_DECODER_LAYERS,
        dim_feedforward: int = FFN_HID_DIM,
        dropout: float = DROPOUT,
        max_len: int = MAX_LEN
    ):
        super(TransformerModel, self).__init__()
        self.emb_size = emb_size
        self.src_tok_emb = nn.Embedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = nn.Embedding(tgt_vocab_size, emb_size)
        self.pos_enc = PositionalEncoding(emb_size, maxlen=max_len + 5)

        self.transformer = nn.Transformer(
            d_model=emb_size,
            nhead=nhead,
            num_encoder_layers=num_encoder_layers,
            num_decoder_layers=num_decoder_layers,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=False  # we use (seq_len, batch, emb)
        )

        self.generator = nn.Linear(emb_size, tgt_vocab_size)

        self._reset_parameters()

    def _reset_parameters(self):
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(
        self,
        src: torch.LongTensor,
        tgt: torch.LongTensor,
        src_key_padding_mask: torch.BoolTensor = None,
        tgt_key_padding_mask: torch.BoolTensor = None,
        tgt_mask: torch.Tensor = None
    ) -> torch.Tensor:
        """
        src: (S, N)
        tgt: (T, N) -- input to decoder (with <sos> at start)
        returns logits: (T, N, V_tgt)
        """
        src_emb = self.src_tok_emb(src) * math.sqrt(self.emb_size)   # (S, N, E)
        tgt_emb = self.tgt_tok_emb(tgt) * math.sqrt(self.emb_size)   # (T, N, E)

        src_emb = self.pos_enc(src_emb)
        tgt_emb = self.pos_enc(tgt_emb)

        output = self.transformer(
            src=src_emb,
            tgt=tgt_emb,
            tgt_mask=tgt_mask,
            src_key_padding_mask=src_key_padding_mask,
            tgt_key_padding_mask=tgt_key_padding_mask,
            memory_key_padding_mask=src_key_padding_mask
        )  # (T, N, E)

        logits = self.generator(output)  # (T, N, V_tgt)
        return logits

    def encode(self, src: torch.LongTensor, src_key_padding_mask: torch.BoolTensor):
        """Return encoded memory for a given src (useful during inference)."""
        src_emb = self.src_tok_emb(src) * math.sqrt(self.emb_size)
        src_emb = self.pos_enc(src_emb)
        return self.transformer.encoder(src_emb, src_key_padding_mask=src_key_padding_mask)

    def decode(self, tgt: torch.LongTensor, memory: torch.Tensor,
               tgt_key_padding_mask: torch.BoolTensor = None,
               memory_key_padding_mask: torch.BoolTensor = None,
               tgt_mask: torch.Tensor = None):
        """Run only the decoder stack (useful during greedy inference)."""
        tgt_emb = self.tgt_tok_emb(tgt) * math.sqrt(self.emb_size)
        tgt_emb = self.pos_enc(tgt_emb)
        return self.transformer.decoder(
            tgt=tgt_emb,
            memory=memory,
            tgt_mask=tgt_mask,
            tgt_key_padding_mask=tgt_key_padding_mask,
            memory_key_padding_mask=memory_key_padding_mask
        )

# %%
# -----------------------------
# Mask helper: subsequent mask untuk decoder autoregressive
# -----------------------------
def generate_square_subsequent_mask(sz: int) -> torch.Tensor:
    """
    Returns an upper-triangular matrix filled with -inf (masked) and 0 (allowed),
    shape (sz, sz). This is the mask used to prevent attention to future tokens.
    """
    mask = torch.triu(torch.full((sz, sz), float("-inf")), diagonal=1)
    return mask.to(DEVICE)

# %% [markdown]
# ## Training Process - Pelatihan Model
#
# Proses training dilakukan dengan monitoring per-batch untuk memantau performa model secara detail.
#
# ### Fungsi `generate_square_subsequent_mask()`
# Membuat causal mask (subsequent mask) untuk decoder:
# - Mencegah attention melihat token di masa depan (future tokens)
# - Menggunakan upper-triangular matrix dengan nilai -inf untuk posisi yang di-mask
# - Essential untuk autoregressive generation yang benar
#
# ---
#
# ### Fungsi `compute_loss_and_acc()`
# Fungsi evaluasi untuk validation/test set:
#
# **Proses:**
# 1. Set model ke mode evaluasi (`model.eval()`)
# 2. Matikan gradient computation (`torch.no_grad()`)
# 3. Iterasi melalui semua batch dalam dataloader
# 4. Untuk setiap batch:
#    - Forward pass dengan causal mask
#    - Hitung loss (ignore padding tokens)
#    - Hitung accuracy dari prediksi yang benar
# 5. Aggregate loss dan accuracy dari semua batch
# 6. Return ke mode training
#
# **Metrik:**
# - **Loss**: Cross-entropy loss rata-rata per token (excluding padding)
# - **Accuracy**: Persentase token yang diprediksi dengan benar
#
# ---
#
# ### Fungsi `train_one_epoch()`
# Fungsi training untuk satu epoch dengan **monitoring per-batch**:
#
# **Alur training per batch:**
#
# 1. **Data Loading**: Ambil batch data (src, tgt_in, tgt_out, masks)
# 2. **Move to Device**: Transfer semua tensor ke GPU/CPU
# 3. **Create Causal Mask**: Generate subsequent mask untuk decoder
# 4. **Forward Pass**:
#    - Zero gradient dari optimizer
#    - Pass data melalui model
#    - Flatten logits dan target untuk loss computation
# 5. **Backward Pass**:
#    - Hitung loss dengan CrossEntropyLoss
#    - Backpropagation: `loss.backward()`
#    - Gradient clipping untuk stabilitas (max norm = 1.0)
#    - Update weights: `optimizer.step()`
# 6. **Compute Training Metrics**:
#    - Hitung accuracy batch saat ini
#    - Track correct predictions vs total tokens
# 7. **Validation per Batch**:
#    - Jalankan evaluasi pada validation set
#    - Dapatkan ValLoss dan ValAcc
# 8. **Display Metrics**:
#    - **TrainLoss**: Loss dari batch saat ini
#    - **TrainAcc**: Accuracy dari batch saat ini
#    - **ValLoss**: Loss dari seluruh validation set
#    - **ValAcc**: Accuracy dari seluruh validation set
#
# **Output format:**
# ```
# Batch 1/450 | TrainLoss: 5.2341 | TrainAcc: 0.1234 | ValLoss: 5.1234 | ValAcc: 0.1456
# Batch 2/450 | TrainLoss: 5.0123 | TrainAcc: 0.1567 | ValLoss: 4.9876 | ValAcc: 0.1678
# ...
# ```
#
# ---
#
# ### Fungsi `train_with_logging()`
# Versi enhanced dari `train_one_epoch()` dengan logging untuk visualisasi:
#
# **Fitur tambahan:**
# - Menyimpan semua metrics ke dictionary untuk plotting
# - Log fields: batch number, train_loss, train_acc, val_loss, val_acc
# - Return logs untuk visualisasi grafik
#
# ### Fungsi `plot_training_logs()`
# Visualisasi metrics training:
# - **Plot 1**: Training Loss vs Validation Loss per batch
# - **Plot 2**: Training Accuracy vs Validation Accuracy per batch
# - Membantu mengidentifikasi overfitting atau underfitting
# - Monitoring konvergensi model secara visual

# %%
# -----------------------------
# Training dan Evaluasi
# -----------------------------
import torch.nn.functional as F

# Fungsi evaluasi (val/test)
def compute_loss_and_acc(model, dataloader, criterion, tgt_vocab, device=DEVICE):
    model.eval()
    total_loss = 0.0
    total_tokens = 0
    correct_tokens = 0
    pad_id = tgt_vocab.stoi["<pad>"]

    with torch.no_grad():
        for src, tgt_in, tgt_out, src_mask, tgt_mask in dataloader:
            src, tgt_in, tgt_out = src.to(device), tgt_in.to(device), tgt_out.to(device)
            src_mask, tgt_mask = src_mask.to(device), tgt_mask.to(device)

            tgt_seq_len = tgt_in.size(0)
            mask = generate_square_subsequent_mask(tgt_seq_len)

            logits = model(
                src, tgt_in,
                src_key_padding_mask=src_mask,
                tgt_key_padding_mask=tgt_mask,
                tgt_mask=mask
            )

            logits_flat = logits.reshape(-1, logits.size(-1))
            tgt_flat = tgt_out.reshape(-1)

            loss = criterion(logits_flat, tgt_flat)
            total_loss += loss.item() * (tgt_flat != pad_id).sum().item()

            preds = logits_flat.argmax(dim=1)
            mask = tgt_flat != pad_id
            correct_tokens += (preds[mask] == tgt_flat[mask]).sum().item()
            total_tokens += mask.sum().item()

    avg_loss = total_loss / max(total_tokens, 1)
    avg_acc = correct_tokens / max(total_tokens, 1)
    model.train()
    return avg_loss, avg_acc



# Fungsi training 1 epoch
def train_one_epoch(model, optimizer, criterion, train_loader, val_loader, tgt_vocab, device=DEVICE):
    model.train()
    pad_id = tgt_vocab.stoi["<pad>"]

    for batch_idx, (src, tgt_in, tgt_out, src_mask, tgt_mask) in enumerate(train_loader, start=1):
        src, tgt_in, tgt_out = src.to(device), tgt_in.to(device), tgt_out.to(device)
        src_mask, tgt_mask = src_mask.to(device), tgt_mask.to(device)

        tgt_seq_len = tgt_in.size(0)
        mask = generate_square_subsequent_mask(tgt_seq_len)

        optimizer.zero_grad()
        logits = model(
            src, tgt_in,
            src_key_padding_mask=src_mask,
            tgt_key_padding_mask=tgt_mask,
            tgt_mask=mask
        )

        # gunakan reshape untuk keamanan
        logits_flat = logits.reshape(-1, logits.size(-1))
        tgt_flat = tgt_out.reshape(-1)

        loss = criterion(logits_flat, tgt_flat)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        # Hitung akurasi batch
        with torch.no_grad():
            preds = logits_flat.argmax(dim=1)
            mask = tgt_flat != pad_id
            correct = (preds[mask] == tgt_flat[mask]).sum().item()
            total = mask.sum().item()
            train_acc = correct / max(total, 1)

        # Evaluasi val per batch
        val_loss, val_acc = compute_loss_and_acc(model, val_loader, criterion, tgt_vocab, device)

        print(f"Batch {batch_idx}/{len(train_loader)} | "
              f"TrainLoss: {loss.item():.4f} | TrainAcc: {train_acc:.4f} | "
              f"ValLoss: {val_loss:.4f} | ValAcc: {val_acc:.4f}")

# %%
import matplotlib.pyplot as plt

# -----------------------------
# Training dengan logging hasil per batch
# -----------------------------
def train_with_logging(model, optimizer, criterion, train_loader, val_loader, tgt_vocab, device=DEVICE):
    model.train()
    pad_id = tgt_vocab.stoi["<pad>"]

    # Simpan log
    logs = {
        "batch": [],
        "train_loss": [],
        "train_acc": [],
        "val_loss": [],
        "val_acc": []
    }

    for batch_idx, (src, tgt_in, tgt_out, src_mask, tgt_mask) in enumerate(train_loader, start=1):
        src, tgt_in, tgt_out = src.to(device), tgt_in.to(device), tgt_out.to(device)
        src_mask, tgt_mask = src_mask.to(device), tgt_mask.to(device)

        tgt_seq_len = tgt_in.size(0)
        mask = generate_square_subsequent_mask(tgt_seq_len)

        optimizer.zero_grad()
        logits = model(
            src, tgt_in,
            src_key_padding_mask=src_mask,
            tgt_key_padding_mask=tgt_mask,
            tgt_mask=mask
        )

        logits_flat = logits.view(-1, logits.size(-1))
        tgt_flat = tgt_out.view(-1)
        loss = criterion(logits_flat, tgt_flat)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        # Hitung akurasi batch
        with torch.no_grad():
            preds = logits_flat.argmax(dim=1)
            mask = tgt_flat != pad_id
            correct = (preds[mask] == tgt_flat[mask]).sum().item()
            total = mask.sum().item()
            train_acc = correct / max(total, 1)

        # Evaluasi val per batch
        val_loss, val_acc = compute_loss_and_acc(model, val_loader, criterion, tgt_vocab, device)

        # Simpan ke log
        logs["batch"].append(batch_idx)
        logs["train_loss"].append(loss.item())
        logs["train_acc"].append(train_acc)
        logs["val_loss"].append(val_loss)
        logs["val_acc"].append(val_acc)

        print(f"Batch {batch_idx}/{len(train_loader)} | "
              f"TrainLoss: {loss.item():.4f} | TrainAcc: {train_acc:.4f} | "
              f"ValLoss: {val_loss:.4f} | ValAcc: {val_acc:.4f}")

    return logs


# -----------------------------
# Fungsi visualisasi grafik loss & accuracy
# -----------------------------
def plot_training_logs(logs):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(logs["batch"], logs["train_loss"], label="Train Loss")
    plt.plot(logs["batch"], logs["val_loss"], label="Val Loss")
    plt.xlabel("Batch")
    plt.ylabel("Loss")
    plt.title("Training & Validation Loss per Batch")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(logs["batch"], logs["train_acc"], label="Train Accuracy")
    plt.plot(logs["batch"], logs["val_acc"], label="Val Accuracy")
    plt.xlabel("Batch")
    plt.ylabel("Accuracy")
    plt.title("Training & Validation Accuracy per Batch")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Model Inference - Proses Translation
#
# Setelah model di-train, tahap inference digunakan untuk melakukan translation dari English ke Russian.
#
# ### Fungsi `translate_sentence()`
# Implementasi **greedy decoding** untuk generate translation secara autoregressive.
#
# **Alur proses inference:**
#
# #### 1. Preprocessing Input
# ```python
# tokens = tokenize(sentence)[:max_len]
# src_ids = src_vocab.tokens_to_ids(tokens)
# src_tensor = torch.LongTensor([src_ids]).transpose(0, 1).to(device)
# ```
# - Tokenisasi kalimat input
# - Konversi token ke ID numerik
# - Buat tensor dengan shape (seq_len, 1)
# - Transfer ke device (GPU/CPU)
#
# #### 2. Encode Source Sentence (Sekali)
# ```python
# memory = model.encode(src_tensor, src_mask)
# ```
# - Jalankan encoder untuk mendapatkan representation dari source sentence
# - Memory ini akan digunakan berulang kali di decoder
# - Efisien karena encoding hanya dilakukan sekali
#
# #### 3. Greedy Decoding (Iteratif)
# Proses generate token satu per satu:
#
# **Inisialisasi:**
# - Mulai dengan `<sos>` token sebagai input decoder
# - `ys = [[<sos>]]`
#
# **Loop untuk setiap posisi (max_len):**
#
# a. **Generate Causal Mask**
#    - Buat subsequent mask sesuai panjang sequence saat ini
#    - Mencegah attention ke future positions
#
# b. **Decode**
#    - Pass current sequence melalui decoder
#    - Input: sequence yang sudah digenerate, memory dari encoder
#    - Output: hidden states
#
# c. **Generate Logits**
#    - Pass hidden state terakhir melalui generator layer
#    - Dapatkan probability distribution untuk semua vocabulary
#
# d. **Select Next Token (Greedy)**
#    - Pilih token dengan probability tertinggi: `argmax(logits)`
#    - Ini adalah strategi "greedy" - selalu pilih yang terbaik
#
# e. **Append Token**
#    - Tambahkan token baru ke sequence
#    - `ys = torch.cat([ys, next_token])`
#
# f. **Check Stopping Condition**
#    - Jika token adalah `<eos>`, stop generation
#    - Atau jika sudah mencapai max_len
#
# #### 4. Post-processing Output
# ```python
# out_ids.remove(<sos>)
# out_ids = out_ids[:out_ids.index(<eos>)]
# tokens_out = tgt_vocab.ids_to_tokens(out_ids)
# return " ".join(tokens_out)
# ```
# - Hapus `<sos>` token dari hasil
# - Potong sequence setelah `<eos>` token
# - Konversi ID kembali ke token strings
# - Join token menjadi kalimat lengkap
#
# **Karakteristik Greedy Decoding:**
# - ✅ Cepat dan deterministik
# - ✅ Sederhana untuk diimplementasikan
# - ❌ Tidak selalu menghasilkan translation terbaik secara global
# - ❌ Tidak bisa "melihat ke belakang" untuk memperbaiki pilihan sebelumnya
#
# **Alternative strategies** (tidak diimplementasikan di sini):
# - **Beam Search**: Maintain top-k candidates untuk hasil lebih baik
# - **Sampling**: Random sampling dari distribution untuk variasi output
# - **Temperature**: Control randomness dalam generation

# %%
# -----------------------------
# Fungsi terjemahan (greedy decoding)
# -----------------------------
def translate_sentence(model, sentence, src_vocab, tgt_vocab, max_len=MAX_LEN, device=DEVICE):
    model.eval()
    tokens = tokenize(sentence)[:max_len]
    src_ids = src_vocab.tokens_to_ids(tokens)
    src_tensor = torch.LongTensor([src_ids]).transpose(0, 1).to(device)
    src_mask = (src_tensor.transpose(0, 1) == src_vocab.stoi["<pad>"]).to(device)

    with torch.no_grad():
        memory = model.encode(src_tensor, src_mask)
        ys = torch.LongTensor([[tgt_vocab.stoi["<sos>"]]]).to(device)

        for i in range(max_len):
            tgt_mask = generate_square_subsequent_mask(ys.size(0))
            out = model.decode(
                ys, memory,
                tgt_key_padding_mask=(ys.transpose(0, 1) == tgt_vocab.stoi["<pad>"]),
                memory_key_padding_mask=src_mask,
                tgt_mask=tgt_mask
            )
            out = out.transpose(0, 1)
            logits = model.generator(out[:, -1, :])
            _, next_word = torch.max(logits, dim=1)
            next_word = next_word.item()
            ys = torch.cat([ys, torch.LongTensor([[next_word]]).to(device)], dim=0)
            if next_word == tgt_vocab.stoi["<eos>"]:
                break

    out_ids = ys.squeeze(1).cpu().numpy().tolist()
    if tgt_vocab.stoi["<sos>"] in out_ids:
        out_ids.remove(tgt_vocab.stoi["<sos>"])
    if tgt_vocab.stoi["<eos>"] in out_ids:
        out_ids = out_ids[:out_ids.index(tgt_vocab.stoi["<eos>"])]

    tokens_out = tgt_vocab.ids_to_tokens(out_ids)
    return " ".join(tokens_out)

# %%
# -----------------------------
# Main training loop
# -----------------------------
def main():
    print("Loading dataset...")
    df = pd.read_csv(DATA_PATH)
    src_texts = df[SRC_COL].tolist()
    tgt_texts = df[TGT_COL].tolist()

    # Split ulang (jaga konsistensi)
    pairs = list(zip(src_texts, tgt_texts))
    random.shuffle(pairs)
    train_split = int(0.8 * len(pairs))
    val_split = int(0.1 * len(pairs))

    train_data = pairs[:train_split]
    val_data = pairs[train_split:train_split + val_split]
    test_data = pairs[train_split + val_split:]

    train_src, train_tgt = zip(*train_data)
    val_src, val_tgt = zip(*val_data)
    test_src, test_tgt = zip(*test_data)

    # Dataset dan DataLoader
    train_dataset = TranslationDataset(train_src, train_tgt, src_vocab, tgt_vocab)
    val_dataset = TranslationDataset(val_src, val_tgt, src_vocab, tgt_vocab)
    test_dataset = TranslationDataset(test_src, test_tgt, src_vocab, tgt_vocab)

    collate = lambda b: collate_fn(b, src_vocab, tgt_vocab)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate)

    # Model setup
    model = TransformerModel(len(src_vocab), len(tgt_vocab)).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    pad_id = tgt_vocab.stoi["<pad>"]
    criterion = nn.CrossEntropyLoss(ignore_index=pad_id)

    # Training 1 epoch
    print("Starting training...\n")
    for epoch in range(1, NUM_EPOCHS + 1):
        print(f"=== Epoch {epoch}/{NUM_EPOCHS} ===")
        train_one_epoch(model, optimizer, criterion, train_loader, val_loader, tgt_vocab)

    # Evaluasi akhir
    test_loss, test_acc = compute_loss_and_acc(model, test_loader, criterion, tgt_vocab)
    print(f"\nFinal Test Loss: {test_loss:.4f} | Final Test Accuracy: {test_acc:.4f}")

    # Contoh inferensi
    print("\n--- Translation Examples ---")
    examples = [
        "Hello, how are you?",
        "I love programming and coffee.",
        "This is a simple test."
    ]
    for ex in examples:
        translation = translate_sentence(model, ex, src_vocab, tgt_vocab)
        print(f"English: {ex}")
        print(f"Russian: {translation}\n")


# Jalankan training
if __name__ == "__main__":
    main()
# Out:
# Loading dataset...
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Starting training...
#
# === Epoch 1/1 ===
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py:6041: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Batch 1/2908 | TrainLoss: 10.3474 | TrainAcc: 0.0000 | ValLoss: 10.3330 | ValAcc: 0.0000
# Batch 2/2908 | TrainLoss: 10.3341 | TrainAcc: 0.0016 | ValLoss: 10.3111 | ValAcc: 0.0000
# Batch 3/2908 | TrainLoss: 10.3074 | TrainAcc: 0.0000 | ValLoss: 10.2892 | ValAcc: 0.0001
# Batch 4/2908 | TrainLoss: 10.2875 | TrainAcc: 0.0049 | ValLoss: 10.2676 | ValAcc: 0.0228
# Batch 5/2908 | TrainLoss: 10.2743 | TrainAcc: 0.0179 | ValLoss: 10.2464 | ValAcc: 0.0923
# Batch 6/2908 | TrainLoss: 10.2572 | TrainAcc: 0.0580 | ValLoss: 10.2257 | ValAcc: 0.1447
# Batch 7/2908 | TrainLoss: 10.2254 | TrainAcc: 0.1302 | ValLoss: 10.2055 | ValAcc: 0.1601
# Batch 8/2908 | TrainLoss: 10.2193 | TrainAcc: 0.1564 | ValLoss: 10.1859 | ValAcc: 0.1606
# Batch 9/2908 | TrainLoss: 10.1997 | TrainAcc: 0.1616 | ValLoss: 10.1670 | ValAcc: 0.1606
# Batch 10/2908 | TrainLoss: 10.1825 | TrainAcc: 0.1493 | ValLoss: 10.1486 | ValAcc: 0.1606
# Batch 11/2908 | TrainLoss: 10.1526 | TrainAcc: 0.1634 | ValLoss: 10.1307 | ValAcc: 0.1606
# Batch 12/2908 | TrainLoss: 10.1429 | TrainAcc: 0.1639 | ValLoss: 10.1134 | ValAcc: 0.1606
# Batch 13/2908 | TrainLoss: 10.1404 | TrainAcc: 0.1664 | ValLoss: 10.0964 | ValAcc: 0.1606
# Batch 14/2908 | TrainLoss: 10.1199 | TrainAcc: 0.1529 | ValLoss: 10.0798 | ValAcc: 0.1606
# Batch 15/2908 | TrainLoss: 10.0915 | TrainAcc: 0.1603 | ValLoss: 10.0635 | ValAcc: 0.1606
# Batch 16/2908 | TrainLoss: 10.0784 | TrainAcc: 0.1672 | ValLoss: 10.0474 | ValAcc: 0.1606
# Batch 17/2908 | TrainLoss: 10.0590 | TrainAcc: 0.1600 | ValLoss: 10.0314 | ValAcc: 0.1606
# Batch 18/2908 | TrainLoss: 10.0490 | TrainAcc: 0.1650 | ValLoss: 10.0154 | ValAcc: 0.1606
# Batch 19/2908 | TrainLoss: 10.0495 | TrainAcc: 0.1555 | ValLoss: 9.9995 | ValAcc: 0.1606
# Batch 20/2908 | TrainLoss: 10.0133 | TrainAcc: 0.1560 | ValLoss: 9.9835 | ValAcc: 0.1606
# Batch 21/2908 | TrainLoss: 10.0118 | TrainAcc: 0.1524 | ValLoss: 9.9674 | ValAcc: 0.1606
# Batch 22/2908 | TrainLoss: 9.9794 | TrainAcc: 0.1658 | ValLoss: 9.9514 | ValAcc: 0.1606
# Batch 23/2908 | TrainLoss: 9.9614 | TrainAcc: 0.1704 | ValLoss: 9.9353 | ValAcc: 0.1606
# Batch 24/2908 | TrainLoss: 9.9620 | TrainAcc: 0.1637 | ValLoss: 9.9193 | ValAcc: 0.1606
# Batch 25/2908 | TrainLoss: 9.9367 | TrainAcc: 0.1587 | ValLoss: 9.9031 | ValAcc: 0.1606
# Batch 26/2908 | TrainLoss: 9.9320 | TrainAcc: 0.1575 | ValLoss: 9.8869 | ValAcc: 0.1606
# Batch 27/2908 | TrainLoss: 9.9052 | TrainAcc: 0.1558 | ValLoss: 9.8706 | ValAcc: 0.1606
# Batch 28/2908 | TrainLoss: 9.9020 | TrainAcc: 0.1600 | ValLoss: 9.8542 | ValAcc: 0.1606
# Batch 29/2908 | TrainLoss: 9.8818 | TrainAcc: 0.1567 | ValLoss: 9.8378 | ValAcc: 0.1606
# Batch 30/2908 | TrainLoss: 9.8772 | TrainAcc: 0.1678 | ValLoss: 9.8215 | ValAcc: 0.1606
# Batch 31/2908 | TrainLoss: 9.8518 | TrainAcc: 0.1631 | ValLoss: 9.8051 | ValAcc: 0.1606
# Batch 32/2908 | TrainLoss: 9.8296 | TrainAcc: 0.1597 | ValLoss: 9.7886 | ValAcc: 0.1606
# Batch 33/2908 | TrainLoss: 9.8113 | TrainAcc: 0.1613 | ValLoss: 9.7721 | ValAcc: 0.1606
# Batch 34/2908 | TrainLoss: 9.7975 | TrainAcc: 0.1575 | ValLoss: 9.7556 | ValAcc: 0.1606
# Batch 35/2908 | TrainLoss: 9.7961 | TrainAcc: 0.1661 | ValLoss: 9.7391 | ValAcc: 0.1606
# Batch 36/2908 | TrainLoss: 9.7801 | TrainAcc: 0.1669 | ValLoss: 9.7226 | ValAcc: 0.1606
# Batch 37/2908 | TrainLoss: 9.7333 | TrainAcc: 0.1577 | ValLoss: 9.7060 | ValAcc: 0.1606
# Batch 38/2908 | TrainLoss: 9.7416 | TrainAcc: 0.1541 | ValLoss: 9.6894 | ValAcc: 0.1606
# Batch 39/2908 | TrainLoss: 9.7146 | TrainAcc: 0.1667 | ValLoss: 9.6728 | ValAcc: 0.1606
# Batch 40/2908 | TrainLoss: 9.7183 | TrainAcc: 0.1595 | ValLoss: 9.6561 | ValAcc: 0.1606
# Batch 41/2908 | TrainLoss: 9.6972 | TrainAcc: 0.1639 | ValLoss: 9.6395 | ValAcc: 0.1606
# Batch 42/2908 | TrainLoss: 9.6553 | TrainAcc: 0.1678 | ValLoss: 9.6229 | ValAcc: 0.1606
# Batch 43/2908 | TrainLoss: 9.6303 | TrainAcc: 0.1558 | ValLoss: 9.6063 | ValAcc: 0.1606
# Batch 44/2908 | TrainLoss: 9.6282 | TrainAcc: 0.1592 | ValLoss: 9.5896 | ValAcc: 0.1606
# Batch 45/2908 | TrainLoss: 9.6346 | TrainAcc: 0.1570 | ValLoss: 9.5729 | ValAcc: 0.1606
# Batch 46/2908 | TrainLoss: 9.5997 | TrainAcc: 0.1631 | ValLoss: 9.5562 | ValAcc: 0.1606
# Batch 47/2908 | TrainLoss: 9.5798 | TrainAcc: 0.1565 | ValLoss: 9.5394 | ValAcc: 0.1606
# Batch 48/2908 | TrainLoss: 9.5773 | TrainAcc: 0.1642 | ValLoss: 9.5226 | ValAcc: 0.1606
# Batch 49/2908 | TrainLoss: 9.5571 | TrainAcc: 0.1508 | ValLoss: 9.5058 | ValAcc: 0.1606
# Batch 50/2908 | TrainLoss: 9.5296 | TrainAcc: 0.1603 | ValLoss: 9.4890 | ValAcc: 0.1606
# Batch 51/2908 | TrainLoss: 9.5246 | TrainAcc: 0.1642 | ValLoss: 9.4722 | ValAcc: 0.1606
# Batch 52/2908 | TrainLoss: 9.5277 | TrainAcc: 0.1597 | ValLoss: 9.4555 | ValAcc: 0.1606
# Batch 53/2908 | TrainLoss: 9.5056 | TrainAcc: 0.1637 | ValLoss: 9.4389 | ValAcc: 0.1606
# Batch 54/2908 | TrainLoss: 9.4762 | TrainAcc: 0.1631 | ValLoss: 9.4222 | ValAcc: 0.1606
# Batch 55/2908 | TrainLoss: 9.4880 | TrainAcc: 0.1555 | ValLoss: 9.4056 | ValAcc: 0.1606
# Batch 56/2908 | TrainLoss: 9.4435 | TrainAcc: 0.1580 | ValLoss: 9.3890 | ValAcc: 0.1606
# Batch 57/2908 | TrainLoss: 9.4200 | TrainAcc: 0.1585 | ValLoss: 9.3724 | ValAcc: 0.1606
# Batch 58/2908 | TrainLoss: 9.3934 | TrainAcc: 0.1597 | ValLoss: 9.3558 | ValAcc: 0.1606
# Batch 59/2908 | TrainLoss: 9.3805 | TrainAcc: 0.1520 | ValLoss: 9.3391 | ValAcc: 0.1606
# Batch 60/2908 | TrainLoss: 9.3837 | TrainAcc: 0.1577 | ValLoss: 9.3225 | ValAcc: 0.1606
# Batch 61/2908 | TrainLoss: 9.3489 | TrainAcc: 0.1779 | ValLoss: 9.3060 | ValAcc: 0.1606
# Batch 62/2908 | TrainLoss: 9.3419 | TrainAcc: 0.1672 | ValLoss: 9.2895 | ValAcc: 0.1606
# Batch 63/2908 | TrainLoss: 9.3067 | TrainAcc: 0.1595 | ValLoss: 9.2730 | ValAcc: 0.1606
# Batch 64/2908 | TrainLoss: 9.3371 | TrainAcc: 0.1513 | ValLoss: 9.2566 | ValAcc: 0.1606
# Batch 65/2908 | TrainLoss: 9.3138 | TrainAcc: 0.1656 | ValLoss: 9.2402 | ValAcc: 0.1606
# Batch 66/2908 | TrainLoss: 9.2781 | TrainAcc: 0.1629 | ValLoss: 9.2238 | ValAcc: 0.1606
# Batch 67/2908 | TrainLoss: 9.2838 | TrainAcc: 0.1585 | ValLoss: 9.2075 | ValAcc: 0.1606
# Batch 68/2908 | TrainLoss: 9.2463 | TrainAcc: 0.1667 | ValLoss: 9.1913 | ValAcc: 0.1606
# Batch 69/2908 | TrainLoss: 9.2579 | TrainAcc: 0.1639 | ValLoss: 9.1751 | ValAcc: 0.1606
# Batch 70/2908 | TrainLoss: 9.2441 | TrainAcc: 0.1661 | ValLoss: 9.1590 | ValAcc: 0.1606
# Batch 71/2908 | TrainLoss: 9.1822 | TrainAcc: 0.1587 | ValLoss: 9.1428 | ValAcc: 0.1606
# Batch 72/2908 | TrainLoss: 9.1815 | TrainAcc: 0.1553 | ValLoss: 9.1267 | ValAcc: 0.1606
# Batch 73/2908 | TrainLoss: 9.1814 | TrainAcc: 0.1639 | ValLoss: 9.1107 | ValAcc: 0.1606
# Batch 74/2908 | TrainLoss: 9.1436 | TrainAcc: 0.1600 | ValLoss: 9.0947 | ValAcc: 0.1606
# Batch 75/2908 | TrainLoss: 9.1363 | TrainAcc: 0.1629 | ValLoss: 9.0787 | ValAcc: 0.1606
# Batch 76/2908 | TrainLoss: 9.0953 | TrainAcc: 0.1653 | ValLoss: 9.0628 | ValAcc: 0.1606
# Batch 77/2908 | TrainLoss: 9.1057 | TrainAcc: 0.1684 | ValLoss: 9.0470 | ValAcc: 0.1606
# Batch 78/2908 | TrainLoss: 9.0705 | TrainAcc: 0.1608 | ValLoss: 9.0312 | ValAcc: 0.1606
# Batch 79/2908 | TrainLoss: 9.0416 | TrainAcc: 0.1479 | ValLoss: 9.0153 | ValAcc: 0.1606
# Batch 80/2908 | TrainLoss: 9.0651 | TrainAcc: 0.1653 | ValLoss: 8.9995 | ValAcc: 0.1606
# Batch 81/2908 | TrainLoss: 9.0388 | TrainAcc: 0.1621 | ValLoss: 8.9837 | ValAcc: 0.1606
# Batch 82/2908 | TrainLoss: 9.0329 | TrainAcc: 0.1656 | ValLoss: 8.9680 | ValAcc: 0.1606
# Batch 83/2908 | TrainLoss: 9.0102 | TrainAcc: 0.1669 | ValLoss: 8.9523 | ValAcc: 0.1606
# Batch 84/2908 | TrainLoss: 9.0069 | TrainAcc: 0.1621 | ValLoss: 8.9368 | ValAcc: 0.1606
# Batch 85/2908 | TrainLoss: 8.9814 | TrainAcc: 0.1592 | ValLoss: 8.9212 | ValAcc: 0.1606
# Batch 86/2908 | TrainLoss: 8.9553 | TrainAcc: 0.1575 | ValLoss: 8.9057 | ValAcc: 0.1606
# Batch 87/2908 | TrainLoss: 8.9432 | TrainAcc: 0.1605 | ValLoss: 8.8902 | ValAcc: 0.1606
# Batch 88/2908 | TrainLoss: 8.9910 | TrainAcc: 0.1597 | ValLoss: 8.8748 | ValAcc: 0.1606
# Batch 89/2908 | TrainLoss: 8.9511 | TrainAcc: 0.1585 | ValLoss: 8.8594 | ValAcc: 0.1606
# Batch 90/2908 | TrainLoss: 8.8783 | TrainAcc: 0.1531 | ValLoss: 8.8440 | ValAcc: 0.1606
# Batch 91/2908 | TrainLoss: 8.8563 | TrainAcc: 0.1531 | ValLoss: 8.8286 | ValAcc: 0.1606
# Batch 92/2908 | TrainLoss: 8.9475 | TrainAcc: 0.1672 | ValLoss: 8.8133 | ValAcc: 0.1606
# Batch 93/2908 | TrainLoss: 8.8644 | TrainAcc: 0.1522 | ValLoss: 8.7980 | ValAcc: 0.1606
# Batch 94/2908 | TrainLoss: 8.8006 | TrainAcc: 0.1629 | ValLoss: 8.7828 | ValAcc: 0.1606
# Batch 95/2908 | TrainLoss: 8.8656 | TrainAcc: 0.1546 | ValLoss: 8.7677 | ValAcc: 0.1606
# Batch 96/2908 | TrainLoss: 8.8336 | TrainAcc: 0.1647 | ValLoss: 8.7526 | ValAcc: 0.1606
# Batch 97/2908 | TrainLoss: 8.8486 | TrainAcc: 0.1653 | ValLoss: 8.7376 | ValAcc: 0.1606
# Batch 98/2908 | TrainLoss: 8.7690 | TrainAcc: 0.1629 | ValLoss: 8.7226 | ValAcc: 0.1606
# Batch 99/2908 | TrainLoss: 8.7870 | TrainAcc: 0.1600 | ValLoss: 8.7077 | ValAcc: 0.1606
# Batch 100/2908 | TrainLoss: 8.7317 | TrainAcc: 0.1585 | ValLoss: 8.6929 | ValAcc: 0.1606
# Batch 101/2908 | TrainLoss: 8.7678 | TrainAcc: 0.1618 | ValLoss: 8.6781 | ValAcc: 0.1606
# Batch 102/2908 | TrainLoss: 8.7105 | TrainAcc: 0.1637 | ValLoss: 8.6633 | ValAcc: 0.1606
# Batch 103/2908 | TrainLoss: 8.6762 | TrainAcc: 0.1570 | ValLoss: 8.6486 | ValAcc: 0.1606
# Batch 104/2908 | TrainLoss: 8.6622 | TrainAcc: 0.1626 | ValLoss: 8.6340 | ValAcc: 0.1606
# Batch 105/2908 | TrainLoss: 8.6487 | TrainAcc: 0.1570 | ValLoss: 8.6193 | ValAcc: 0.1606
# Batch 106/2908 | TrainLoss: 8.6419 | TrainAcc: 0.1637 | ValLoss: 8.6048 | ValAcc: 0.1606
# Batch 107/2908 | TrainLoss: 8.7150 | TrainAcc: 0.1686 | ValLoss: 8.5903 | ValAcc: 0.1606
# Batch 108/2908 | TrainLoss: 8.6350 | TrainAcc: 0.1592 | ValLoss: 8.5759 | ValAcc: 0.1606
# Batch 109/2908 | TrainLoss: 8.6244 | TrainAcc: 0.1567 | ValLoss: 8.5615 | ValAcc: 0.1606
# Batch 110/2908 | TrainLoss: 8.5973 | TrainAcc: 0.1536 | ValLoss: 8.5471 | ValAcc: 0.1606
# Batch 111/2908 | TrainLoss: 8.6874 | TrainAcc: 0.1595 | ValLoss: 8.5328 | ValAcc: 0.1606
# Batch 112/2908 | TrainLoss: 8.6591 | TrainAcc: 0.1541 | ValLoss: 8.5185 | ValAcc: 0.1606
# Batch 113/2908 | TrainLoss: 8.5834 | TrainAcc: 0.1553 | ValLoss: 8.5042 | ValAcc: 0.1606
# Batch 114/2908 | TrainLoss: 8.5521 | TrainAcc: 0.1577 | ValLoss: 8.4900 | ValAcc: 0.1606
# Batch 115/2908 | TrainLoss: 8.5648 | TrainAcc: 0.1560 | ValLoss: 8.4758 | ValAcc: 0.1606
# Batch 116/2908 | TrainLoss: 8.5018 | TrainAcc: 0.1548 | ValLoss: 8.4617 | ValAcc: 0.1606
# Batch 117/2908 | TrainLoss: 8.4721 | TrainAcc: 0.1664 | ValLoss: 8.4476 | ValAcc: 0.1606
# Batch 118/2908 | TrainLoss: 8.4928 | TrainAcc: 0.1639 | ValLoss: 8.4336 | ValAcc: 0.1606
# Batch 119/2908 | TrainLoss: 8.4644 | TrainAcc: 0.1587 | ValLoss: 8.4197 | ValAcc: 0.1606
# Batch 120/2908 | TrainLoss: 8.4862 | TrainAcc: 0.1623 | ValLoss: 8.4058 | ValAcc: 0.1606
# Batch 121/2908 | TrainLoss: 8.4208 | TrainAcc: 0.1603 | ValLoss: 8.3919 | ValAcc: 0.1606
# Batch 122/2908 | TrainLoss: 8.4240 | TrainAcc: 0.1597 | ValLoss: 8.3781 | ValAcc: 0.1606
# Batch 123/2908 | TrainLoss: 8.4070 | TrainAcc: 0.1631 | ValLoss: 8.3644 | ValAcc: 0.1606
# Batch 124/2908 | TrainLoss: 8.3973 | TrainAcc: 0.1558 | ValLoss: 8.3506 | ValAcc: 0.1606
# Batch 125/2908 | TrainLoss: 8.3964 | TrainAcc: 0.1618 | ValLoss: 8.3370 | ValAcc: 0.1606
# Batch 126/2908 | TrainLoss: 8.4010 | TrainAcc: 0.1567 | ValLoss: 8.3234 | ValAcc: 0.1606
# Batch 127/2908 | TrainLoss: 8.3554 | TrainAcc: 0.1522 | ValLoss: 8.3098 | ValAcc: 0.1606
# Batch 128/2908 | TrainLoss: 8.3536 | TrainAcc: 0.1555 | ValLoss: 8.2963 | ValAcc: 0.1606
# Batch 129/2908 | TrainLoss: 8.3046 | TrainAcc: 0.1669 | ValLoss: 8.2828 | ValAcc: 0.1606
# Batch 130/2908 | TrainLoss: 8.3604 | TrainAcc: 0.1695 | ValLoss: 8.2694 | ValAcc: 0.1606
# Batch 131/2908 | TrainLoss: 8.3841 | TrainAcc: 0.1626 | ValLoss: 8.2562 | ValAcc: 0.1606
# Batch 132/2908 | TrainLoss: 8.3289 | TrainAcc: 0.1522 | ValLoss: 8.2429 | ValAcc: 0.1606
# Batch 133/2908 | TrainLoss: 8.2985 | TrainAcc: 0.1658 | ValLoss: 8.2298 | ValAcc: 0.1606
# Batch 134/2908 | TrainLoss: 8.2727 | TrainAcc: 0.1575 | ValLoss: 8.2166 | ValAcc: 0.1606
# Batch 135/2908 | TrainLoss: 8.2000 | TrainAcc: 0.1621 | ValLoss: 8.2035 | ValAcc: 0.1606
# Batch 136/2908 | TrainLoss: 8.2310 | TrainAcc: 0.1639 | ValLoss: 8.1905 | ValAcc: 0.1606
# Batch 137/2908 | TrainLoss: 8.2603 | TrainAcc: 0.1709 | ValLoss: 8.1776 | ValAcc: 0.1606
# Batch 138/2908 | TrainLoss: 8.2369 | TrainAcc: 0.1538 | ValLoss: 8.1647 | ValAcc: 0.1606
# Batch 139/2908 | TrainLoss: 8.2120 | TrainAcc: 0.1616 | ValLoss: 8.1519 | ValAcc: 0.1606
# Batch 140/2908 | TrainLoss: 8.1910 | TrainAcc: 0.1524 | ValLoss: 8.1391 | ValAcc: 0.1606
# Batch 141/2908 | TrainLoss: 8.1586 | TrainAcc: 0.1608 | ValLoss: 8.1263 | ValAcc: 0.1606
# Batch 142/2908 | TrainLoss: 8.2471 | TrainAcc: 0.1575 | ValLoss: 8.1135 | ValAcc: 0.1606
# Batch 143/2908 | TrainLoss: 8.0930 | TrainAcc: 0.1502 | ValLoss: 8.1008 | ValAcc: 0.1606
# Batch 144/2908 | TrainLoss: 8.1178 | TrainAcc: 0.1653 | ValLoss: 8.0881 | ValAcc: 0.1606
# Batch 145/2908 | TrainLoss: 8.1324 | TrainAcc: 0.1650 | ValLoss: 8.0756 | ValAcc: 0.1606
# Batch 146/2908 | TrainLoss: 8.1235 | TrainAcc: 0.1580 | ValLoss: 8.0630 | ValAcc: 0.1606
# Batch 147/2908 | TrainLoss: 8.1188 | TrainAcc: 0.1664 | ValLoss: 8.0506 | ValAcc: 0.1606
# Batch 148/2908 | TrainLoss: 8.0849 | TrainAcc: 0.1613 | ValLoss: 8.0382 | ValAcc: 0.1606
# Batch 149/2908 | TrainLoss: 8.0841 | TrainAcc: 0.1560 | ValLoss: 8.0258 | ValAcc: 0.1606
# Batch 150/2908 | TrainLoss: 8.0913 | TrainAcc: 0.1570 | ValLoss: 8.0135 | ValAcc: 0.1606
# Batch 151/2908 | TrainLoss: 8.0413 | TrainAcc: 0.1739 | ValLoss: 8.0013 | ValAcc: 0.1606
# Batch 152/2908 | TrainLoss: 8.0797 | TrainAcc: 0.1656 | ValLoss: 7.9892 | ValAcc: 0.1606
# Batch 153/2908 | TrainLoss: 8.1399 | TrainAcc: 0.1548 | ValLoss: 7.9771 | ValAcc: 0.1606
# Batch 154/2908 | TrainLoss: 8.0699 | TrainAcc: 0.1629 | ValLoss: 7.9651 | ValAcc: 0.1606
# Batch 155/2908 | TrainLoss: 7.9738 | TrainAcc: 0.1490 | ValLoss: 7.9531 | ValAcc: 0.1606
# Batch 156/2908 | TrainLoss: 8.0417 | TrainAcc: 0.1661 | ValLoss: 7.9411 | ValAcc: 0.1606
# Batch 157/2908 | TrainLoss: 7.9811 | TrainAcc: 0.1621 | ValLoss: 7.9292 | ValAcc: 0.1606
# Batch 158/2908 | TrainLoss: 7.9663 | TrainAcc: 0.1629 | ValLoss: 7.9173 | ValAcc: 0.1606
# Batch 159/2908 | TrainLoss: 8.0274 | TrainAcc: 0.1637 | ValLoss: 7.9055 | ValAcc: 0.1606
# Batch 160/2908 | TrainLoss: 7.8943 | TrainAcc: 0.1560 | ValLoss: 7.8937 | ValAcc: 0.1606
# Batch 161/2908 | TrainLoss: 7.8668 | TrainAcc: 0.1560 | ValLoss: 7.8819 | ValAcc: 0.1606
# Batch 162/2908 | TrainLoss: 7.9679 | TrainAcc: 0.1546 | ValLoss: 7.8702 | ValAcc: 0.1606
# Batch 163/2908 | TrainLoss: 7.9104 | TrainAcc: 0.1548 | ValLoss: 7.8585 | ValAcc: 0.1606
# Batch 164/2908 | TrainLoss: 7.8992 | TrainAcc: 0.1631 | ValLoss: 7.8468 | ValAcc: 0.1606
# Batch 165/2908 | TrainLoss: 7.9640 | TrainAcc: 0.1511 | ValLoss: 7.8352 | ValAcc: 0.1606
# Batch 166/2908 | TrainLoss: 7.9039 | TrainAcc: 0.1580 | ValLoss: 7.8236 | ValAcc: 0.1606
# Batch 167/2908 | TrainLoss: 7.8750 | TrainAcc: 0.1610 | ValLoss: 7.8121 | ValAcc: 0.1606
# Batch 168/2908 | TrainLoss: 7.8660 | TrainAcc: 0.1698 | ValLoss: 7.8007 | ValAcc: 0.1606
# Batch 169/2908 | TrainLoss: 7.8294 | TrainAcc: 0.1603 | ValLoss: 7.7893 | ValAcc: 0.1606
# Batch 170/2908 | TrainLoss: 7.8266 | TrainAcc: 0.1661 | ValLoss: 7.7780 | ValAcc: 0.1606
# Batch 171/2908 | TrainLoss: 7.8296 | TrainAcc: 0.1536 | ValLoss: 7.7668 | ValAcc: 0.1606
# Batch 172/2908 | TrainLoss: 7.7810 | TrainAcc: 0.1667 | ValLoss: 7.7556 | ValAcc: 0.1606
# Batch 173/2908 | TrainLoss: 7.7891 | TrainAcc: 0.1686 | ValLoss: 7.7444 | ValAcc: 0.1606
# Batch 174/2908 | TrainLoss: 7.8010 | TrainAcc: 0.1689 | ValLoss: 7.7334 | ValAcc: 0.1606
# Batch 175/2908 | TrainLoss: 7.8050 | TrainAcc: 0.1629 | ValLoss: 7.7223 | ValAcc: 0.1606
# Batch 176/2908 | TrainLoss: 7.8203 | TrainAcc: 0.1587 | ValLoss: 7.7113 | ValAcc: 0.1606
# Batch 177/2908 | TrainLoss: 7.7571 | TrainAcc: 0.1642 | ValLoss: 7.7004 | ValAcc: 0.1606
# Batch 178/2908 | TrainLoss: 7.8043 | TrainAcc: 0.1605 | ValLoss: 7.6895 | ValAcc: 0.1606
# Batch 179/2908 | TrainLoss: 7.7715 | TrainAcc: 0.1585 | ValLoss: 7.6787 | ValAcc: 0.1606
# Batch 180/2908 | TrainLoss: 7.7000 | TrainAcc: 0.1541 | ValLoss: 7.6679 | ValAcc: 0.1606
# Batch 181/2908 | TrainLoss: 7.7517 | TrainAcc: 0.1585 | ValLoss: 7.6572 | ValAcc: 0.1606
# Batch 182/2908 | TrainLoss: 7.8596 | TrainAcc: 0.1502 | ValLoss: 7.6465 | ValAcc: 0.1606
# Batch 183/2908 | TrainLoss: 7.6485 | TrainAcc: 0.1698 | ValLoss: 7.6359 | ValAcc: 0.1606
# Batch 184/2908 | TrainLoss: 7.7010 | TrainAcc: 0.1582 | ValLoss: 7.6253 | ValAcc: 0.1606
# Batch 185/2908 | TrainLoss: 7.6730 | TrainAcc: 0.1527 | ValLoss: 7.6147 | ValAcc: 0.1606
# Batch 186/2908 | TrainLoss: 7.7258 | TrainAcc: 0.1605 | ValLoss: 7.6042 | ValAcc: 0.1606
# Batch 187/2908 | TrainLoss: 7.6802 | TrainAcc: 0.1623 | ValLoss: 7.5937 | ValAcc: 0.1606
# Batch 188/2908 | TrainLoss: 7.5370 | TrainAcc: 0.1575 | ValLoss: 7.5832 | ValAcc: 0.1606
# Batch 189/2908 | TrainLoss: 7.5934 | TrainAcc: 0.1572 | ValLoss: 7.5727 | ValAcc: 0.1606
# Batch 190/2908 | TrainLoss: 7.5948 | TrainAcc: 0.1565 | ValLoss: 7.5623 | ValAcc: 0.1606
# Batch 191/2908 | TrainLoss: 7.6351 | TrainAcc: 0.1692 | ValLoss: 7.5519 | ValAcc: 0.1606
# Batch 192/2908 | TrainLoss: 7.6923 | TrainAcc: 0.1560 | ValLoss: 7.5416 | ValAcc: 0.1606
# Batch 193/2908 | TrainLoss: 7.6341 | TrainAcc: 0.1580 | ValLoss: 7.5313 | ValAcc: 0.1606
# Batch 194/2908 | TrainLoss: 7.5083 | TrainAcc: 0.1706 | ValLoss: 7.5211 | ValAcc: 0.1606
# Batch 195/2908 | TrainLoss: 7.6065 | TrainAcc: 0.1650 | ValLoss: 7.5110 | ValAcc: 0.1606
# Batch 196/2908 | TrainLoss: 7.5350 | TrainAcc: 0.1669 | ValLoss: 7.5010 | ValAcc: 0.1606
# Batch 197/2908 | TrainLoss: 7.5738 | TrainAcc: 0.1672 | ValLoss: 7.4911 | ValAcc: 0.1606
# Batch 198/2908 | TrainLoss: 7.5687 | TrainAcc: 0.1618 | ValLoss: 7.4812 | ValAcc: 0.1606
# Batch 199/2908 | TrainLoss: 7.4142 | TrainAcc: 0.1616 | ValLoss: 7.4713 | ValAcc: 0.1606
# Batch 200/2908 | TrainLoss: 7.6304 | TrainAcc: 0.1621 | ValLoss: 7.4614 | ValAcc: 0.1606
# Batch 201/2908 | TrainLoss: 7.6206 | TrainAcc: 0.1546 | ValLoss: 7.4516 | ValAcc: 0.1606
# Batch 202/2908 | TrainLoss: 7.6133 | TrainAcc: 0.1701 | ValLoss: 7.4419 | ValAcc: 0.1606
# Batch 203/2908 | TrainLoss: 7.5490 | TrainAcc: 0.1502 | ValLoss: 7.4322 | ValAcc: 0.1606
# Batch 204/2908 | TrainLoss: 7.5415 | TrainAcc: 0.1600 | ValLoss: 7.4225 | ValAcc: 0.1606
# Batch 205/2908 | TrainLoss: 7.5685 | TrainAcc: 0.1709 | ValLoss: 7.4130 | ValAcc: 0.1606
# Batch 206/2908 | TrainLoss: 7.5540 | TrainAcc: 0.1621 | ValLoss: 7.4034 | ValAcc: 0.1606
# Batch 207/2908 | TrainLoss: 7.3519 | TrainAcc: 0.1527 | ValLoss: 7.3939 | ValAcc: 0.1606
# Batch 208/2908 | TrainLoss: 7.3494 | TrainAcc: 0.1605 | ValLoss: 7.3843 | ValAcc: 0.1606
# Batch 209/2908 | TrainLoss: 7.4887 | TrainAcc: 0.1605 | ValLoss: 7.3748 | ValAcc: 0.1606
# Batch 210/2908 | TrainLoss: 7.3962 | TrainAcc: 0.1610 | ValLoss: 7.3654 | ValAcc: 0.1606
# Batch 211/2908 | TrainLoss: 7.3654 | TrainAcc: 0.1575 | ValLoss: 7.3560 | ValAcc: 0.1606
# Batch 212/2908 | TrainLoss: 7.4321 | TrainAcc: 0.1587 | ValLoss: 7.3466 | ValAcc: 0.1606
# Batch 213/2908 | TrainLoss: 7.3897 | TrainAcc: 0.1724 | ValLoss: 7.3373 | ValAcc: 0.1606
# Batch 214/2908 | TrainLoss: 7.4911 | TrainAcc: 0.1626 | ValLoss: 7.3280 | ValAcc: 0.1606
# Batch 215/2908 | TrainLoss: 7.4958 | TrainAcc: 0.1626 | ValLoss: 7.3189 | ValAcc: 0.1606
# Batch 216/2908 | TrainLoss: 7.2903 | TrainAcc: 0.1555 | ValLoss: 7.3097 | ValAcc: 0.1606
# Batch 217/2908 | TrainLoss: 7.2683 | TrainAcc: 0.1572 | ValLoss: 7.3006 | ValAcc: 0.1606
# Batch 218/2908 | TrainLoss: 7.3679 | TrainAcc: 0.1629 | ValLoss: 7.2915 | ValAcc: 0.1606
# Batch 219/2908 | TrainLoss: 7.4051 | TrainAcc: 0.1567 | ValLoss: 7.2825 | ValAcc: 0.1606
# Batch 220/2908 | TrainLoss: 7.3209 | TrainAcc: 0.1558 | ValLoss: 7.2735 | ValAcc: 0.1606
# Batch 221/2908 | TrainLoss: 7.2196 | TrainAcc: 0.1618 | ValLoss: 7.2645 | ValAcc: 0.1606
# Batch 222/2908 | TrainLoss: 7.2956 | TrainAcc: 0.1658 | ValLoss: 7.2555 | ValAcc: 0.1606
# Batch 223/2908 | TrainLoss: 7.3506 | TrainAcc: 0.1553 | ValLoss: 7.2466 | ValAcc: 0.1606
# Batch 224/2908 | TrainLoss: 7.1846 | TrainAcc: 0.1661 | ValLoss: 7.2377 | ValAcc: 0.1606
# Batch 225/2908 | TrainLoss: 7.3152 | TrainAcc: 0.1678 | ValLoss: 7.2289 | ValAcc: 0.1606
# Batch 226/2908 | TrainLoss: 7.3680 | TrainAcc: 0.1590 | ValLoss: 7.2202 | ValAcc: 0.1606
# Batch 227/2908 | TrainLoss: 7.3297 | TrainAcc: 0.1486 | ValLoss: 7.2115 | ValAcc: 0.1606
# Batch 228/2908 | TrainLoss: 7.3213 | TrainAcc: 0.1642 | ValLoss: 7.2028 | ValAcc: 0.1606
# Batch 229/2908 | TrainLoss: 7.2160 | TrainAcc: 0.1661 | ValLoss: 7.1942 | ValAcc: 0.1606
# Batch 230/2908 | TrainLoss: 7.2701 | TrainAcc: 0.1570 | ValLoss: 7.1856 | ValAcc: 0.1606
# Batch 231/2908 | TrainLoss: 7.1797 | TrainAcc: 0.1513 | ValLoss: 7.1769 | ValAcc: 0.1606
# Batch 232/2908 | TrainLoss: 7.2216 | TrainAcc: 0.1595 | ValLoss: 7.1684 | ValAcc: 0.1606
# Batch 233/2908 | TrainLoss: 7.2043 | TrainAcc: 0.1629 | ValLoss: 7.1599 | ValAcc: 0.1606
# Batch 234/2908 | TrainLoss: 7.1719 | TrainAcc: 0.1565 | ValLoss: 7.1514 | ValAcc: 0.1606
# Batch 235/2908 | TrainLoss: 7.1856 | TrainAcc: 0.1553 | ValLoss: 7.1430 | ValAcc: 0.1606
# Batch 236/2908 | TrainLoss: 7.1666 | TrainAcc: 0.1631 | ValLoss: 7.1346 | ValAcc: 0.1606
# Batch 237/2908 | TrainLoss: 7.1544 | TrainAcc: 0.1730 | ValLoss: 7.1263 | ValAcc: 0.1606
# Batch 238/2908 | TrainLoss: 7.1302 | TrainAcc: 0.1639 | ValLoss: 7.1180 | ValAcc: 0.1606
# Batch 239/2908 | TrainLoss: 7.2433 | TrainAcc: 0.1613 | ValLoss: 7.1098 | ValAcc: 0.1606
# Batch 240/2908 | TrainLoss: 7.1587 | TrainAcc: 0.1603 | ValLoss: 7.1016 | ValAcc: 0.1606
# Batch 241/2908 | TrainLoss: 7.1184 | TrainAcc: 0.1565 | ValLoss: 7.0935 | ValAcc: 0.1606
# Batch 242/2908 | TrainLoss: 7.1417 | TrainAcc: 0.1595 | ValLoss: 7.0854 | ValAcc: 0.1606
# Batch 243/2908 | TrainLoss: 7.1411 | TrainAcc: 0.1555 | ValLoss: 7.0773 | ValAcc: 0.1606
# Batch 244/2908 | TrainLoss: 7.0593 | TrainAcc: 0.1642 | ValLoss: 7.0693 | ValAcc: 0.1606
# Batch 245/2908 | TrainLoss: 7.1297 | TrainAcc: 0.1587 | ValLoss: 7.0613 | ValAcc: 0.1606
# Batch 246/2908 | TrainLoss: 7.0327 | TrainAcc: 0.1548 | ValLoss: 7.0533 | ValAcc: 0.1606
# Batch 247/2908 | TrainLoss: 7.1511 | TrainAcc: 0.1597 | ValLoss: 7.0453 | ValAcc: 0.1606
# Batch 248/2908 | TrainLoss: 7.0849 | TrainAcc: 0.1629 | ValLoss: 7.0374 | ValAcc: 0.1606
# Batch 249/2908 | TrainLoss: 7.0798 | TrainAcc: 0.1597 | ValLoss: 7.0296 | ValAcc: 0.1606
# Batch 250/2908 | TrainLoss: 7.0584 | TrainAcc: 0.1664 | ValLoss: 7.0218 | ValAcc: 0.1606
# Batch 251/2908 | TrainLoss: 7.0759 | TrainAcc: 0.1538 | ValLoss: 7.0141 | ValAcc: 0.1606
# Batch 252/2908 | TrainLoss: 7.0744 | TrainAcc: 0.1600 | ValLoss: 7.0064 | ValAcc: 0.1606
# Batch 253/2908 | TrainLoss: 7.1889 | TrainAcc: 0.1585 | ValLoss: 6.9988 | ValAcc: 0.1606
# Batch 254/2908 | TrainLoss: 7.0903 | TrainAcc: 0.1600 | ValLoss: 6.9911 | ValAcc: 0.1606
# Batch 255/2908 | TrainLoss: 6.9615 | TrainAcc: 0.1650 | ValLoss: 6.9836 | ValAcc: 0.1606
# Batch 256/2908 | TrainLoss: 7.0326 | TrainAcc: 0.1595 | ValLoss: 6.9760 | ValAcc: 0.1606
# Batch 257/2908 | TrainLoss: 7.0404 | TrainAcc: 0.1623 | ValLoss: 6.9686 | ValAcc: 0.1606
# Batch 258/2908 | TrainLoss: 6.9729 | TrainAcc: 0.1610 | ValLoss: 6.9612 | ValAcc: 0.1606
# Batch 259/2908 | TrainLoss: 7.2231 | TrainAcc: 0.1479 | ValLoss: 6.9538 | ValAcc: 0.1606
# Batch 260/2908 | TrainLoss: 7.0265 | TrainAcc: 0.1595 | ValLoss: 6.9465 | ValAcc: 0.1606
# Batch 261/2908 | TrainLoss: 7.0691 | TrainAcc: 0.1678 | ValLoss: 6.9393 | ValAcc: 0.1606
# Batch 262/2908 | TrainLoss: 7.1406 | TrainAcc: 0.1534 | ValLoss: 6.9321 | ValAcc: 0.1606
# Batch 263/2908 | TrainLoss: 6.9429 | TrainAcc: 0.1590 | ValLoss: 6.9249 | ValAcc: 0.1606
# Batch 264/2908 | TrainLoss: 6.9243 | TrainAcc: 0.1631 | ValLoss: 6.9178 | ValAcc: 0.1606
# Batch 265/2908 | TrainLoss: 6.9617 | TrainAcc: 0.1590 | ValLoss: 6.9107 | ValAcc: 0.1606
# Batch 266/2908 | TrainLoss: 6.9528 | TrainAcc: 0.1616 | ValLoss: 6.9036 | ValAcc: 0.1606
# Batch 267/2908 | TrainLoss: 6.9847 | TrainAcc: 0.1645 | ValLoss: 6.8966 | ValAcc: 0.1606
# Batch 268/2908 | TrainLoss: 6.8791 | TrainAcc: 0.1595 | ValLoss: 6.8896 | ValAcc: 0.1606
# Batch 269/2908 | TrainLoss: 6.9021 | TrainAcc: 0.1761 | ValLoss: 6.8827 | ValAcc: 0.1606
# Batch 270/2908 | TrainLoss: 6.9378 | TrainAcc: 0.1597 | ValLoss: 6.8758 | ValAcc: 0.1606
# Batch 271/2908 | TrainLoss: 6.9443 | TrainAcc: 0.1661 | ValLoss: 6.8690 | ValAcc: 0.1606
# Batch 272/2908 | TrainLoss: 6.9405 | TrainAcc: 0.1562 | ValLoss: 6.8622 | ValAcc: 0.1606
# Batch 273/2908 | TrainLoss: 6.9297 | TrainAcc: 0.1639 | ValLoss: 6.8554 | ValAcc: 0.1606
# Batch 274/2908 | TrainLoss: 6.9809 | TrainAcc: 0.1626 | ValLoss: 6.8487 | ValAcc: 0.1606
# Batch 275/2908 | TrainLoss: 6.9359 | TrainAcc: 0.1577 | ValLoss: 6.8421 | ValAcc: 0.1606
# Batch 276/2908 | TrainLoss: 7.1363 | TrainAcc: 0.1603 | ValLoss: 6.8355 | ValAcc: 0.1606
# Batch 277/2908 | TrainLoss: 6.8009 | TrainAcc: 0.1631 | ValLoss: 6.8289 | ValAcc: 0.1606
# Batch 278/2908 | TrainLoss: 6.7786 | TrainAcc: 0.1558 | ValLoss: 6.8223 | ValAcc: 0.1606
# Batch 279/2908 | TrainLoss: 6.7865 | TrainAcc: 0.1664 | ValLoss: 6.8157 | ValAcc: 0.1606
# Batch 280/2908 | TrainLoss: 6.8196 | TrainAcc: 0.1527 | ValLoss: 6.8092 | ValAcc: 0.1606
# Batch 281/2908 | TrainLoss: 6.8223 | TrainAcc: 0.1592 | ValLoss: 6.8026 | ValAcc: 0.1606
# Batch 282/2908 | TrainLoss: 6.8348 | TrainAcc: 0.1667 | ValLoss: 6.7962 | ValAcc: 0.1606
# Batch 283/2908 | TrainLoss: 6.8369 | TrainAcc: 0.1603 | ValLoss: 6.7898 | ValAcc: 0.1606
# Batch 284/2908 | TrainLoss: 6.8103 | TrainAcc: 0.1595 | ValLoss: 6.7834 | ValAcc: 0.1606
# Batch 285/2908 | TrainLoss: 6.9460 | TrainAcc: 0.1634 | ValLoss: 6.7771 | ValAcc: 0.1606
# Batch 286/2908 | TrainLoss: 6.8880 | TrainAcc: 0.1712 | ValLoss: 6.7709 | ValAcc: 0.1606
# Batch 287/2908 | TrainLoss: 6.7546 | TrainAcc: 0.1610 | ValLoss: 6.7647 | ValAcc: 0.1606
# Batch 288/2908 | TrainLoss: 6.9046 | TrainAcc: 0.1562 | ValLoss: 6.7585 | ValAcc: 0.1606
# Batch 289/2908 | TrainLoss: 6.7886 | TrainAcc: 0.1695 | ValLoss: 6.7523 | ValAcc: 0.1606
# Batch 290/2908 | TrainLoss: 6.8919 | TrainAcc: 0.1550 | ValLoss: 6.7462 | ValAcc: 0.1606
# Batch 291/2908 | TrainLoss: 6.8359 | TrainAcc: 0.1543 | ValLoss: 6.7402 | ValAcc: 0.1606
# Batch 292/2908 | TrainLoss: 6.7643 | TrainAcc: 0.1570 | ValLoss: 6.7342 | ValAcc: 0.1606
# Batch 293/2908 | TrainLoss: 6.7492 | TrainAcc: 0.1590 | ValLoss: 6.7282 | ValAcc: 0.1606
# Batch 294/2908 | TrainLoss: 6.7460 | TrainAcc: 0.1513 | ValLoss: 6.7222 | ValAcc: 0.1606
# Batch 295/2908 | TrainLoss: 6.7443 | TrainAcc: 0.1629 | ValLoss: 6.7162 | ValAcc: 0.1606
# Batch 296/2908 | TrainLoss: 6.7555 | TrainAcc: 0.1639 | ValLoss: 6.7104 | ValAcc: 0.1606
# Batch 297/2908 | TrainLoss: 6.7853 | TrainAcc: 0.1605 | ValLoss: 6.7045 | ValAcc: 0.1606
# Batch 298/2908 | TrainLoss: 6.7815 | TrainAcc: 0.1675 | ValLoss: 6.6987 | ValAcc: 0.1606
# Batch 299/2908 | TrainLoss: 6.7576 | TrainAcc: 0.1610 | ValLoss: 6.6930 | ValAcc: 0.1606
# Batch 300/2908 | TrainLoss: 6.6278 | TrainAcc: 0.1650 | ValLoss: 6.6872 | ValAcc: 0.1606
# Batch 301/2908 | TrainLoss: 6.8461 | TrainAcc: 0.1562 | ValLoss: 6.6815 | ValAcc: 0.1606
# Batch 302/2908 | TrainLoss: 6.5975 | TrainAcc: 0.1692 | ValLoss: 6.6758 | ValAcc: 0.1606
# Batch 303/2908 | TrainLoss: 6.7313 | TrainAcc: 0.1560 | ValLoss: 6.6702 | ValAcc: 0.1606
# Batch 304/2908 | TrainLoss: 6.7018 | TrainAcc: 0.1618 | ValLoss: 6.6646 | ValAcc: 0.1606
# Batch 305/2908 | TrainLoss: 6.6681 | TrainAcc: 0.1587 | ValLoss: 6.6590 | ValAcc: 0.1606
# Batch 306/2908 | TrainLoss: 6.6428 | TrainAcc: 0.1631 | ValLoss: 6.6535 | ValAcc: 0.1606
# Batch 307/2908 | TrainLoss: 6.8256 | TrainAcc: 0.1605 | ValLoss: 6.6480 | ValAcc: 0.1606
# Batch 308/2908 | TrainLoss: 6.6264 | TrainAcc: 0.1497 | ValLoss: 6.6425 | ValAcc: 0.1606
# Batch 309/2908 | TrainLoss: 6.7705 | TrainAcc: 0.1629 | ValLoss: 6.6370 | ValAcc: 0.1606
# Batch 310/2908 | TrainLoss: 6.7168 | TrainAcc: 0.1730 | ValLoss: 6.6316 | ValAcc: 0.1606
# Batch 311/2908 | TrainLoss: 6.6929 | TrainAcc: 0.1582 | ValLoss: 6.6263 | ValAcc: 0.1606
# Batch 312/2908 | TrainLoss: 6.5389 | TrainAcc: 0.1605 | ValLoss: 6.6209 | ValAcc: 0.1606
# Batch 313/2908 | TrainLoss: 6.6042 | TrainAcc: 0.1577 | ValLoss: 6.6156 | ValAcc: 0.1606
# Batch 314/2908 | TrainLoss: 6.5364 | TrainAcc: 0.1639 | ValLoss: 6.6103 | ValAcc: 0.1606
# Batch 315/2908 | TrainLoss: 6.7748 | TrainAcc: 0.1511 | ValLoss: 6.6051 | ValAcc: 0.1606
# Batch 316/2908 | TrainLoss: 6.7541 | TrainAcc: 0.1585 | ValLoss: 6.5999 | ValAcc: 0.1606
# Batch 317/2908 | TrainLoss: 6.6028 | TrainAcc: 0.1582 | ValLoss: 6.5947 | ValAcc: 0.1606
# Batch 318/2908 | TrainLoss: 6.5918 | TrainAcc: 0.1570 | ValLoss: 6.5895 | ValAcc: 0.1606
# Batch 319/2908 | TrainLoss: 6.7493 | TrainAcc: 0.1626 | ValLoss: 6.5845 | ValAcc: 0.1606
# Batch 320/2908 | TrainLoss: 6.6067 | TrainAcc: 0.1572 | ValLoss: 6.5794 | ValAcc: 0.1606
# Batch 321/2908 | TrainLoss: 6.5789 | TrainAcc: 0.1647 | ValLoss: 6.5745 | ValAcc: 0.1606
# Batch 322/2908 | TrainLoss: 6.7023 | TrainAcc: 0.1590 | ValLoss: 6.5695 | ValAcc: 0.1606
# Batch 323/2908 | TrainLoss: 6.6125 | TrainAcc: 0.1742 | ValLoss: 6.5647 | ValAcc: 0.1606
# Batch 324/2908 | TrainLoss: 6.5065 | TrainAcc: 0.1631 | ValLoss: 6.5599 | ValAcc: 0.1606
# Batch 325/2908 | TrainLoss: 6.5750 | TrainAcc: 0.1565 | ValLoss: 6.5551 | ValAcc: 0.1606
# Batch 326/2908 | TrainLoss: 6.7587 | TrainAcc: 0.1541 | ValLoss: 6.5503 | ValAcc: 0.1606
# Batch 327/2908 | TrainLoss: 6.6337 | TrainAcc: 0.1637 | ValLoss: 6.5456 | ValAcc: 0.1606
# Batch 328/2908 | TrainLoss: 6.4087 | TrainAcc: 0.1506 | ValLoss: 6.5408 | ValAcc: 0.1606
# Batch 329/2908 | TrainLoss: 6.7120 | TrainAcc: 0.1597 | ValLoss: 6.5361 | ValAcc: 0.1606
# Batch 330/2908 | TrainLoss: 6.6344 | TrainAcc: 0.1575 | ValLoss: 6.5315 | ValAcc: 0.1606
# Batch 331/2908 | TrainLoss: 6.6265 | TrainAcc: 0.1534 | ValLoss: 6.5268 | ValAcc: 0.1606
# Batch 332/2908 | TrainLoss: 6.5640 | TrainAcc: 0.1631 | ValLoss: 6.5223 | ValAcc: 0.1606
# Batch 333/2908 | TrainLoss: 6.6172 | TrainAcc: 0.1587 | ValLoss: 6.5177 | ValAcc: 0.1606
# Batch 334/2908 | TrainLoss: 6.2942 | TrainAcc: 0.1626 | ValLoss: 6.5131 | ValAcc: 0.1606
# Batch 335/2908 | TrainLoss: 6.4210 | TrainAcc: 0.1626 | ValLoss: 6.5086 | ValAcc: 0.1606
# Batch 336/2908 | TrainLoss: 6.4411 | TrainAcc: 0.1520 | ValLoss: 6.5040 | ValAcc: 0.1606
# Batch 337/2908 | TrainLoss: 6.4551 | TrainAcc: 0.1623 | ValLoss: 6.4995 | ValAcc: 0.1606
# Batch 338/2908 | TrainLoss: 6.6841 | TrainAcc: 0.1592 | ValLoss: 6.4951 | ValAcc: 0.1606
# Batch 339/2908 | TrainLoss: 6.4372 | TrainAcc: 0.1629 | ValLoss: 6.4907 | ValAcc: 0.1606
# Batch 340/2908 | TrainLoss: 6.4556 | TrainAcc: 0.1508 | ValLoss: 6.4862 | ValAcc: 0.1606
# Batch 341/2908 | TrainLoss: 6.7053 | TrainAcc: 0.1613 | ValLoss: 6.4819 | ValAcc: 0.1606
# Batch 342/2908 | TrainLoss: 6.6129 | TrainAcc: 0.1595 | ValLoss: 6.4776 | ValAcc: 0.1606
# Batch 343/2908 | TrainLoss: 6.5436 | TrainAcc: 0.1558 | ValLoss: 6.4733 | ValAcc: 0.1606
# Batch 344/2908 | TrainLoss: 6.5877 | TrainAcc: 0.1570 | ValLoss: 6.4691 | ValAcc: 0.1606
# Batch 345/2908 | TrainLoss: 6.4844 | TrainAcc: 0.1590 | ValLoss: 6.4649 | ValAcc: 0.1606
# Batch 346/2908 | TrainLoss: 6.5505 | TrainAcc: 0.1645 | ValLoss: 6.4607 | ValAcc: 0.1606
# Batch 347/2908 | TrainLoss: 6.4777 | TrainAcc: 0.1669 | ValLoss: 6.4566 | ValAcc: 0.1606
# Batch 348/2908 | TrainLoss: 6.3965 | TrainAcc: 0.1511 | ValLoss: 6.4525 | ValAcc: 0.1606
# Batch 349/2908 | TrainLoss: 6.5205 | TrainAcc: 0.1592 | ValLoss: 6.4484 | ValAcc: 0.1606
# Batch 350/2908 | TrainLoss: 6.5454 | TrainAcc: 0.1585 | ValLoss: 6.4443 | ValAcc: 0.1606
# Batch 351/2908 | TrainLoss: 6.3665 | TrainAcc: 0.1623 | ValLoss: 6.4403 | ValAcc: 0.1606
# Batch 352/2908 | TrainLoss: 6.6770 | TrainAcc: 0.1645 | ValLoss: 6.4363 | ValAcc: 0.1606
# Batch 353/2908 | TrainLoss: 6.6040 | TrainAcc: 0.1562 | ValLoss: 6.4324 | ValAcc: 0.1606
# Batch 354/2908 | TrainLoss: 6.3006 | TrainAcc: 0.1681 | ValLoss: 6.4285 | ValAcc: 0.1606
# Batch 355/2908 | TrainLoss: 6.5613 | TrainAcc: 0.1587 | ValLoss: 6.4246 | ValAcc: 0.1606
# Batch 356/2908 | TrainLoss: 6.5533 | TrainAcc: 0.1562 | ValLoss: 6.4208 | ValAcc: 0.1606
# Batch 357/2908 | TrainLoss: 6.3131 | TrainAcc: 0.1653 | ValLoss: 6.4170 | ValAcc: 0.1606
# Batch 358/2908 | TrainLoss: 6.3704 | TrainAcc: 0.1634 | ValLoss: 6.4133 | ValAcc: 0.1606
# Batch 359/2908 | TrainLoss: 6.3688 | TrainAcc: 0.1613 | ValLoss: 6.4096 | ValAcc: 0.1606
# Batch 360/2908 | TrainLoss: 6.5078 | TrainAcc: 0.1715 | ValLoss: 6.4060 | ValAcc: 0.1606
# Batch 361/2908 | TrainLoss: 6.3506 | TrainAcc: 0.1597 | ValLoss: 6.4023 | ValAcc: 0.1606
# Batch 362/2908 | TrainLoss: 6.4854 | TrainAcc: 0.1585 | ValLoss: 6.3988 | ValAcc: 0.1606
# Batch 363/2908 | TrainLoss: 6.3755 | TrainAcc: 0.1565 | ValLoss: 6.3952 | ValAcc: 0.1606
# Batch 364/2908 | TrainLoss: 6.3693 | TrainAcc: 0.1658 | ValLoss: 6.3916 | ValAcc: 0.1606
# Batch 365/2908 | TrainLoss: 6.4025 | TrainAcc: 0.1618 | ValLoss: 6.3880 | ValAcc: 0.1606
# Batch 366/2908 | TrainLoss: 6.4981 | TrainAcc: 0.1580 | ValLoss: 6.3845 | ValAcc: 0.1606
# Batch 367/2908 | TrainLoss: 6.4312 | TrainAcc: 0.1647 | ValLoss: 6.3810 | ValAcc: 0.1606
# Batch 368/2908 | TrainLoss: 6.2526 | TrainAcc: 0.1592 | ValLoss: 6.3775 | ValAcc: 0.1606
# Batch 369/2908 | TrainLoss: 6.4486 | TrainAcc: 0.1582 | ValLoss: 6.3741 | ValAcc: 0.1606
# Batch 370/2908 | TrainLoss: 6.4672 | TrainAcc: 0.1658 | ValLoss: 6.3707 | ValAcc: 0.1606
# Batch 371/2908 | TrainLoss: 6.4894 | TrainAcc: 0.1603 | ValLoss: 6.3674 | ValAcc: 0.1606
# Batch 372/2908 | TrainLoss: 6.4206 | TrainAcc: 0.1592 | ValLoss: 6.3642 | ValAcc: 0.1606
# Batch 373/2908 | TrainLoss: 6.3662 | TrainAcc: 0.1513 | ValLoss: 6.3609 | ValAcc: 0.1606
# Batch 374/2908 | TrainLoss: 6.3767 | TrainAcc: 0.1613 | ValLoss: 6.3577 | ValAcc: 0.1606
# Batch 375/2908 | TrainLoss: 6.2548 | TrainAcc: 0.1637 | ValLoss: 6.3544 | ValAcc: 0.1606
# Batch 376/2908 | TrainLoss: 6.4302 | TrainAcc: 0.1645 | ValLoss: 6.3511 | ValAcc: 0.1606
# Batch 377/2908 | TrainLoss: 6.2647 | TrainAcc: 0.1653 | ValLoss: 6.3479 | ValAcc: 0.1606
# Batch 378/2908 | TrainLoss: 6.3645 | TrainAcc: 0.1626 | ValLoss: 6.3447 | ValAcc: 0.1606
# Batch 379/2908 | TrainLoss: 6.4116 | TrainAcc: 0.1610 | ValLoss: 6.3416 | ValAcc: 0.1606
# Batch 380/2908 | TrainLoss: 6.2737 | TrainAcc: 0.1658 | ValLoss: 6.3385 | ValAcc: 0.1606
# Batch 381/2908 | TrainLoss: 6.2716 | TrainAcc: 0.1484 | ValLoss: 6.3354 | ValAcc: 0.1606
# Batch 382/2908 | TrainLoss: 6.5056 | TrainAcc: 0.1610 | ValLoss: 6.3323 | ValAcc: 0.1606
# Batch 383/2908 | TrainLoss: 6.2232 | TrainAcc: 0.1626 | ValLoss: 6.3292 | ValAcc: 0.1606
# Batch 384/2908 | TrainLoss: 6.4419 | TrainAcc: 0.1642 | ValLoss: 6.3263 | ValAcc: 0.1606
# Batch 385/2908 | TrainLoss: 6.4558 | TrainAcc: 0.1513 | ValLoss: 6.3233 | ValAcc: 0.1606
# Batch 386/2908 | TrainLoss: 6.4265 | TrainAcc: 0.1678 | ValLoss: 6.3204 | ValAcc: 0.1606
# Batch 387/2908 | TrainLoss: 6.3887 | TrainAcc: 0.1634 | ValLoss: 6.3175 | ValAcc: 0.1606
# Batch 388/2908 | TrainLoss: 6.3248 | TrainAcc: 0.1681 | ValLoss: 6.3146 | ValAcc: 0.1606
# Batch 389/2908 | TrainLoss: 6.4007 | TrainAcc: 0.1618 | ValLoss: 6.3117 | ValAcc: 0.1606
# Batch 390/2908 | TrainLoss: 6.3163 | TrainAcc: 0.1618 | ValLoss: 6.3088 | ValAcc: 0.1606
# Batch 391/2908 | TrainLoss: 6.2080 | TrainAcc: 0.1618 | ValLoss: 6.3060 | ValAcc: 0.1606
# Batch 392/2908 | TrainLoss: 6.5283 | TrainAcc: 0.1580 | ValLoss: 6.3032 | ValAcc: 0.1606
# Batch 393/2908 | TrainLoss: 6.3812 | TrainAcc: 0.1610 | ValLoss: 6.3005 | ValAcc: 0.1606
# Batch 394/2908 | TrainLoss: 6.2830 | TrainAcc: 0.1712 | ValLoss: 6.2978 | ValAcc: 0.1606
# Batch 395/2908 | TrainLoss: 6.5722 | TrainAcc: 0.1520 | ValLoss: 6.2951 | ValAcc: 0.1606
# Batch 396/2908 | TrainLoss: 6.3550 | TrainAcc: 0.1585 | ValLoss: 6.2925 | ValAcc: 0.1606
# Batch 397/2908 | TrainLoss: 6.2772 | TrainAcc: 0.1616 | ValLoss: 6.2898 | ValAcc: 0.1606
# Batch 398/2908 | TrainLoss: 6.3487 | TrainAcc: 0.1621 | ValLoss: 6.2871 | ValAcc: 0.1606
# Batch 399/2908 | TrainLoss: 6.3178 | TrainAcc: 0.1650 | ValLoss: 6.2845 | ValAcc: 0.1606
# Batch 400/2908 | TrainLoss: 6.3805 | TrainAcc: 0.1553 | ValLoss: 6.2819 | ValAcc: 0.1606
# Batch 401/2908 | TrainLoss: 6.4833 | TrainAcc: 0.1592 | ValLoss: 6.2793 | ValAcc: 0.1606
# Batch 402/2908 | TrainLoss: 6.1833 | TrainAcc: 0.1626 | ValLoss: 6.2766 | ValAcc: 0.1606
# Batch 403/2908 | TrainLoss: 6.3157 | TrainAcc: 0.1582 | ValLoss: 6.2740 | ValAcc: 0.1606
# Batch 404/2908 | TrainLoss: 6.2786 | TrainAcc: 0.1637 | ValLoss: 6.2714 | ValAcc: 0.1606
# Batch 405/2908 | TrainLoss: 6.3039 | TrainAcc: 0.1555 | ValLoss: 6.2689 | ValAcc: 0.1606
# Batch 406/2908 | TrainLoss: 6.3216 | TrainAcc: 0.1618 | ValLoss: 6.2663 | ValAcc: 0.1606
# Batch 407/2908 | TrainLoss: 6.3492 | TrainAcc: 0.1650 | ValLoss: 6.2637 | ValAcc: 0.1606
# Batch 408/2908 | TrainLoss: 6.3949 | TrainAcc: 0.1548 | ValLoss: 6.2612 | ValAcc: 0.1606
# Batch 409/2908 | TrainLoss: 6.1827 | TrainAcc: 0.1642 | ValLoss: 6.2586 | ValAcc: 0.1606
# Batch 410/2908 | TrainLoss: 6.2167 | TrainAcc: 0.1565 | ValLoss: 6.2562 | ValAcc: 0.1606
# Batch 411/2908 | TrainLoss: 6.3528 | TrainAcc: 0.1616 | ValLoss: 6.2538 | ValAcc: 0.1606
# Batch 412/2908 | TrainLoss: 6.3105 | TrainAcc: 0.1650 | ValLoss: 6.2513 | ValAcc: 0.1606
# Batch 413/2908 | TrainLoss: 6.3290 | TrainAcc: 0.1629 | ValLoss: 6.2488 | ValAcc: 0.1606
# Batch 414/2908 | TrainLoss: 6.2711 | TrainAcc: 0.1506 | ValLoss: 6.2463 | ValAcc: 0.1606
# Batch 415/2908 | TrainLoss: 6.3395 | TrainAcc: 0.1592 | ValLoss: 6.2439 | ValAcc: 0.1606
# Batch 416/2908 | TrainLoss: 6.3136 | TrainAcc: 0.1706 | ValLoss: 6.2416 | ValAcc: 0.1606
# Batch 417/2908 | TrainLoss: 6.3152 | TrainAcc: 0.1486 | ValLoss: 6.2391 | ValAcc: 0.1606
# Batch 418/2908 | TrainLoss: 6.2500 | TrainAcc: 0.1626 | ValLoss: 6.2366 | ValAcc: 0.1606
# Batch 419/2908 | TrainLoss: 6.5360 | TrainAcc: 0.1524 | ValLoss: 6.2340 | ValAcc: 0.1606
# Batch 420/2908 | TrainLoss: 6.2100 | TrainAcc: 0.1650 | ValLoss: 6.2315 | ValAcc: 0.1606
# Batch 421/2908 | TrainLoss: 6.0893 | TrainAcc: 0.1546 | ValLoss: 6.2290 | ValAcc: 0.1606
# Batch 422/2908 | TrainLoss: 6.1392 | TrainAcc: 0.1536 | ValLoss: 6.2266 | ValAcc: 0.1606
# Batch 423/2908 | TrainLoss: 6.2554 | TrainAcc: 0.1629 | ValLoss: 6.2243 | ValAcc: 0.1606
# Batch 424/2908 | TrainLoss: 6.2010 | TrainAcc: 0.1610 | ValLoss: 6.2220 | ValAcc: 0.1606
# Batch 425/2908 | TrainLoss: 6.1086 | TrainAcc: 0.1567 | ValLoss: 6.2196 | ValAcc: 0.1606
# Batch 426/2908 | TrainLoss: 6.3108 | TrainAcc: 0.1577 | ValLoss: 6.2171 | ValAcc: 0.1606
# Batch 427/2908 | TrainLoss: 6.2630 | TrainAcc: 0.1661 | ValLoss: 6.2145 | ValAcc: 0.1606
# Batch 428/2908 | TrainLoss: 6.3613 | TrainAcc: 0.1675 | ValLoss: 6.2120 | ValAcc: 0.1606
# Batch 429/2908 | TrainLoss: 6.2939 | TrainAcc: 0.1616 | ValLoss: 6.2095 | ValAcc: 0.1606
# Batch 430/2908 | TrainLoss: 6.4192 | TrainAcc: 0.1577 | ValLoss: 6.2068 | ValAcc: 0.1606
# Batch 431/2908 | TrainLoss: 6.2152 | TrainAcc: 0.1650 | ValLoss: 6.2042 | ValAcc: 0.1606
# Batch 432/2908 | TrainLoss: 6.1939 | TrainAcc: 0.1623 | ValLoss: 6.2016 | ValAcc: 0.1606
# Batch 433/2908 | TrainLoss: 6.3720 | TrainAcc: 0.1610 | ValLoss: 6.1988 | ValAcc: 0.1606
# Batch 434/2908 | TrainLoss: 6.1751 | TrainAcc: 0.1603 | ValLoss: 6.1961 | ValAcc: 0.1606
# Batch 435/2908 | TrainLoss: 6.2915 | TrainAcc: 0.1513 | ValLoss: 6.1934 | ValAcc: 0.1606
# Batch 436/2908 | TrainLoss: 6.2214 | TrainAcc: 0.1555 | ValLoss: 6.1909 | ValAcc: 0.1606
# Batch 437/2908 | TrainLoss: 6.2027 | TrainAcc: 0.1661 | ValLoss: 6.1884 | ValAcc: 0.1606
# Batch 438/2908 | TrainLoss: 6.3606 | TrainAcc: 0.1529 | ValLoss: 6.1857 | ValAcc: 0.1606
# Batch 439/2908 | TrainLoss: 6.1871 | TrainAcc: 0.1608 | ValLoss: 6.1830 | ValAcc: 0.1606
# Batch 440/2908 | TrainLoss: 6.3673 | TrainAcc: 0.1515 | ValLoss: 6.1804 | ValAcc: 0.1606
# Batch 441/2908 | TrainLoss: 6.0987 | TrainAcc: 0.1590 | ValLoss: 6.1779 | ValAcc: 0.1606
# Batch 442/2908 | TrainLoss: 6.1085 | TrainAcc: 0.1553 | ValLoss: 6.1752 | ValAcc: 0.1606
# Batch 443/2908 | TrainLoss: 6.1807 | TrainAcc: 0.1495 | ValLoss: 6.1730 | ValAcc: 0.1606
# Batch 444/2908 | TrainLoss: 6.3090 | TrainAcc: 0.1692 | ValLoss: 6.1706 | ValAcc: 0.1606
# Batch 445/2908 | TrainLoss: 6.0889 | TrainAcc: 0.1565 | ValLoss: 6.1679 | ValAcc: 0.1606
# Batch 446/2908 | TrainLoss: 6.0406 | TrainAcc: 0.1531 | ValLoss: 6.1648 | ValAcc: 0.1606
# Batch 447/2908 | TrainLoss: 6.1720 | TrainAcc: 0.1739 | ValLoss: 6.1618 | ValAcc: 0.1606
# Batch 448/2908 | TrainLoss: 6.1599 | TrainAcc: 0.1618 | ValLoss: 6.1589 | ValAcc: 0.1606
# Batch 449/2908 | TrainLoss: 6.3334 | TrainAcc: 0.1531 | ValLoss: 6.1556 | ValAcc: 0.1606
# Batch 450/2908 | TrainLoss: 6.1190 | TrainAcc: 0.1603 | ValLoss: 6.1525 | ValAcc: 0.1606
# Batch 451/2908 | TrainLoss: 6.0340 | TrainAcc: 0.1590 | ValLoss: 6.1496 | ValAcc: 0.1606
# Batch 452/2908 | TrainLoss: 6.0363 | TrainAcc: 0.1587 | ValLoss: 6.1468 | ValAcc: 0.1606
# Batch 453/2908 | TrainLoss: 6.1365 | TrainAcc: 0.1664 | ValLoss: 6.1444 | ValAcc: 0.1606
# Batch 454/2908 | TrainLoss: 6.0537 | TrainAcc: 0.1626 | ValLoss: 6.1419 | ValAcc: 0.1606
# Batch 455/2908 | TrainLoss: 6.1399 | TrainAcc: 0.1686 | ValLoss: 6.1389 | ValAcc: 0.1606
# Batch 456/2908 | TrainLoss: 6.0898 | TrainAcc: 0.1522 | ValLoss: 6.1358 | ValAcc: 0.1606
# Batch 457/2908 | TrainLoss: 5.9276 | TrainAcc: 0.1582 | ValLoss: 6.1329 | ValAcc: 0.1606
# Batch 458/2908 | TrainLoss: 6.2312 | TrainAcc: 0.1546 | ValLoss: 6.1299 | ValAcc: 0.1606
# Batch 459/2908 | TrainLoss: 6.1883 | TrainAcc: 0.1653 | ValLoss: 6.1265 | ValAcc: 0.1606
# Batch 460/2908 | TrainLoss: 6.0250 | TrainAcc: 0.1639 | ValLoss: 6.1232 | ValAcc: 0.1606
# Batch 461/2908 | TrainLoss: 6.1715 | TrainAcc: 0.1704 | ValLoss: 6.1194 | ValAcc: 0.1606
# Batch 462/2908 | TrainLoss: 6.2293 | TrainAcc: 0.1658 | ValLoss: 6.1154 | ValAcc: 0.1606
# Batch 463/2908 | TrainLoss: 6.4788 | TrainAcc: 0.1637 | ValLoss: 6.1110 | ValAcc: 0.1611
# Batch 464/2908 | TrainLoss: 5.9787 | TrainAcc: 0.1536 | ValLoss: 6.1080 | ValAcc: 0.1620
# Batch 465/2908 | TrainLoss: 6.1394 | TrainAcc: 0.1726 | ValLoss: 6.1047 | ValAcc: 0.1617
# Batch 466/2908 | TrainLoss: 6.2008 | TrainAcc: 0.1709 | ValLoss: 6.1024 | ValAcc: 0.1610
# Batch 467/2908 | TrainLoss: 6.3003 | TrainAcc: 0.1586 | ValLoss: 6.1015 | ValAcc: 0.1608
# Batch 468/2908 | TrainLoss: 6.1466 | TrainAcc: 0.1524 | ValLoss: 6.0998 | ValAcc: 0.1607
# Batch 469/2908 | TrainLoss: 6.1228 | TrainAcc: 0.1631 | ValLoss: 6.0963 | ValAcc: 0.1607
# Batch 470/2908 | TrainLoss: 5.9991 | TrainAcc: 0.1580 | ValLoss: 6.0919 | ValAcc: 0.1607
# Batch 471/2908 | TrainLoss: 5.8882 | TrainAcc: 0.1647 | ValLoss: 6.0879 | ValAcc: 0.1608
# Batch 472/2908 | TrainLoss: 6.0053 | TrainAcc: 0.1562 | ValLoss: 6.0841 | ValAcc: 0.1608
# Batch 473/2908 | TrainLoss: 6.0212 | TrainAcc: 0.1597 | ValLoss: 6.0807 | ValAcc: 0.1609
# Batch 474/2908 | TrainLoss: 6.1287 | TrainAcc: 0.1601 | ValLoss: 6.0772 | ValAcc: 0.1610
# Batch 475/2908 | TrainLoss: 6.1674 | TrainAcc: 0.1517 | ValLoss: 6.0742 | ValAcc: 0.1612
# Batch 476/2908 | TrainLoss: 6.1304 | TrainAcc: 0.1567 | ValLoss: 6.0707 | ValAcc: 0.1612
# Batch 477/2908 | TrainLoss: 6.2826 | TrainAcc: 0.1610 | ValLoss: 6.0671 | ValAcc: 0.1613
# Batch 478/2908 | TrainLoss: 6.1610 | TrainAcc: 0.1613 | ValLoss: 6.0627 | ValAcc: 0.1615
# Batch 479/2908 | TrainLoss: 6.1225 | TrainAcc: 0.1647 | ValLoss: 6.0591 | ValAcc: 0.1615
# Batch 480/2908 | TrainLoss: 5.8622 | TrainAcc: 0.1639 | ValLoss: 6.0569 | ValAcc: 0.1613
# Batch 481/2908 | TrainLoss: 6.1433 | TrainAcc: 0.1623 | ValLoss: 6.0559 | ValAcc: 0.1610
# Batch 482/2908 | TrainLoss: 5.9610 | TrainAcc: 0.1715 | ValLoss: 6.0551 | ValAcc: 0.1609
# Batch 483/2908 | TrainLoss: 6.1450 | TrainAcc: 0.1558 | ValLoss: 6.0523 | ValAcc: 0.1610
# Batch 484/2908 | TrainLoss: 6.0246 | TrainAcc: 0.1637 | ValLoss: 6.0481 | ValAcc: 0.1613
# Batch 485/2908 | TrainLoss: 6.0183 | TrainAcc: 0.1720 | ValLoss: 6.0426 | ValAcc: 0.1623
# Batch 486/2908 | TrainLoss: 6.0864 | TrainAcc: 0.1553 | ValLoss: 6.0374 | ValAcc: 0.1642
# Batch 487/2908 | TrainLoss: 6.0491 | TrainAcc: 0.1599 | ValLoss: 6.0335 | ValAcc: 0.1651
# Batch 488/2908 | TrainLoss: 6.0623 | TrainAcc: 0.1689 | ValLoss: 6.0303 | ValAcc: 0.1641
# Batch 489/2908 | TrainLoss: 6.1318 | TrainAcc: 0.1610 | ValLoss: 6.0280 | ValAcc: 0.1628
# Batch 490/2908 | TrainLoss: 5.9498 | TrainAcc: 0.1741 | ValLoss: 6.0255 | ValAcc: 0.1623
# Batch 491/2908 | TrainLoss: 5.8457 | TrainAcc: 0.1659 | ValLoss: 6.0238 | ValAcc: 0.1618
# Batch 492/2908 | TrainLoss: 6.1303 | TrainAcc: 0.1632 | ValLoss: 6.0198 | ValAcc: 0.1622
# Batch 493/2908 | TrainLoss: 6.2039 | TrainAcc: 0.1504 | ValLoss: 6.0147 | ValAcc: 0.1631
# Batch 494/2908 | TrainLoss: 6.0176 | TrainAcc: 0.1669 | ValLoss: 6.0094 | ValAcc: 0.1648
# Batch 495/2908 | TrainLoss: 5.9472 | TrainAcc: 0.1728 | ValLoss: 6.0055 | ValAcc: 0.1649
# Batch 496/2908 | TrainLoss: 6.1571 | TrainAcc: 0.1638 | ValLoss: 6.0022 | ValAcc: 0.1639
# Batch 497/2908 | TrainLoss: 6.0333 | TrainAcc: 0.1612 | ValLoss: 6.0000 | ValAcc: 0.1624
# Batch 498/2908 | TrainLoss: 5.8566 | TrainAcc: 0.1653 | ValLoss: 6.0023 | ValAcc: 0.1615
# Batch 499/2908 | TrainLoss: 5.9844 | TrainAcc: 0.1598 | ValLoss: 6.0027 | ValAcc: 0.1616
# Batch 500/2908 | TrainLoss: 5.9929 | TrainAcc: 0.1667 | ValLoss: 5.9983 | ValAcc: 0.1625
# Batch 501/2908 | TrainLoss: 6.1461 | TrainAcc: 0.1656 | ValLoss: 5.9893 | ValAcc: 0.1672
# Batch 502/2908 | TrainLoss: 6.0766 | TrainAcc: 0.1753 | ValLoss: 5.9829 | ValAcc: 0.1762
# Batch 503/2908 | TrainLoss: 6.2314 | TrainAcc: 0.1705 | ValLoss: 5.9793 | ValAcc: 0.1809
# Batch 504/2908 | TrainLoss: 6.0721 | TrainAcc: 0.1832 | ValLoss: 5.9771 | ValAcc: 0.1748
# Batch 505/2908 | TrainLoss: 6.1341 | TrainAcc: 0.1638 | ValLoss: 5.9776 | ValAcc: 0.1707
# Batch 506/2908 | TrainLoss: 5.9200 | TrainAcc: 0.1786 | ValLoss: 5.9807 | ValAcc: 0.1659
# Batch 507/2908 | TrainLoss: 6.0128 | TrainAcc: 0.1702 | ValLoss: 5.9790 | ValAcc: 0.1654
# Batch 508/2908 | TrainLoss: 5.8841 | TrainAcc: 0.1683 | ValLoss: 5.9726 | ValAcc: 0.1699
# Batch 509/2908 | TrainLoss: 5.9719 | TrainAcc: 0.1659 | ValLoss: 5.9645 | ValAcc: 0.1823
# Batch 510/2908 | TrainLoss: 5.8822 | TrainAcc: 0.1801 | ValLoss: 5.9600 | ValAcc: 0.1872
# Batch 511/2908 | TrainLoss: 5.8974 | TrainAcc: 0.1902 | ValLoss: 5.9570 | ValAcc: 0.1880
# Batch 512/2908 | TrainLoss: 5.8929 | TrainAcc: 0.1937 | ValLoss: 5.9539 | ValAcc: 0.1865
# Batch 513/2908 | TrainLoss: 6.0551 | TrainAcc: 0.1805 | ValLoss: 5.9505 | ValAcc: 0.1824
# Batch 514/2908 | TrainLoss: 5.9266 | TrainAcc: 0.1790 | ValLoss: 5.9496 | ValAcc: 0.1796
# Batch 515/2908 | TrainLoss: 6.0391 | TrainAcc: 0.1619 | ValLoss: 5.9504 | ValAcc: 0.1785
# Batch 516/2908 | TrainLoss: 5.9208 | TrainAcc: 0.1644 | ValLoss: 5.9485 | ValAcc: 0.1831
# Batch 517/2908 | TrainLoss: 6.0015 | TrainAcc: 0.1856 | ValLoss: 5.9433 | ValAcc: 0.1863
# Batch 518/2908 | TrainLoss: 5.8806 | TrainAcc: 0.1823 | ValLoss: 5.9363 | ValAcc: 0.1912
# Batch 519/2908 | TrainLoss: 6.1650 | TrainAcc: 0.1925 | ValLoss: 5.9308 | ValAcc: 0.2046
# Batch 520/2908 | TrainLoss: 5.9742 | TrainAcc: 0.2006 | ValLoss: 5.9279 | ValAcc: 0.2119
# Batch 521/2908 | TrainLoss: 5.9440 | TrainAcc: 0.2003 | ValLoss: 5.9249 | ValAcc: 0.2056
# Batch 522/2908 | TrainLoss: 5.9928 | TrainAcc: 0.2010 | ValLoss: 5.9255 | ValAcc: 0.1954
# Batch 523/2908 | TrainLoss: 5.9570 | TrainAcc: 0.1964 | ValLoss: 5.9275 | ValAcc: 0.1908
# Batch 524/2908 | TrainLoss: 6.1489 | TrainAcc: 0.1897 | ValLoss: 5.9271 | ValAcc: 0.1894
# Batch 525/2908 | TrainLoss: 6.1942 | TrainAcc: 0.1935 | ValLoss: 5.9194 | ValAcc: 0.1909
# Batch 526/2908 | TrainLoss: 6.0884 | TrainAcc: 0.1939 | ValLoss: 5.9123 | ValAcc: 0.1948
# Batch 527/2908 | TrainLoss: 5.9451 | TrainAcc: 0.1946 | ValLoss: 5.9079 | ValAcc: 0.2029
# Batch 528/2908 | TrainLoss: 5.9923 | TrainAcc: 0.1879 | ValLoss: 5.9052 | ValAcc: 0.2142
# Batch 529/2908 | TrainLoss: 5.9457 | TrainAcc: 0.2074 | ValLoss: 5.9016 | ValAcc: 0.2212
# Batch 530/2908 | TrainLoss: 5.9435 | TrainAcc: 0.1923 | ValLoss: 5.9012 | ValAcc: 0.2228
# Batch 531/2908 | TrainLoss: 6.0198 | TrainAcc: 0.2120 | ValLoss: 5.9017 | ValAcc: 0.2248
# Batch 532/2908 | TrainLoss: 5.9969 | TrainAcc: 0.2119 | ValLoss: 5.8989 | ValAcc: 0.2272
# Batch 533/2908 | TrainLoss: 5.7969 | TrainAcc: 0.2291 | ValLoss: 5.8933 | ValAcc: 0.2301
# Batch 534/2908 | TrainLoss: 5.9196 | TrainAcc: 0.2328 | ValLoss: 5.8879 | ValAcc: 0.2325
# ...
# Batch 2735/2908 | TrainLoss: 3.9276 | TrainAcc: 0.4747 | ValLoss: 3.7592 | ValAcc: 0.4674
# Batch 2736/2908 | TrainLoss: 4.1941 | TrainAcc: 0.4475 | ValLoss: 3.7603 | ValAcc: 0.4675
# Batch 2737/2908 | TrainLoss: 3.7076 | TrainAcc: 0.4750 | ValLoss: 3.7602 | ValAcc: 0.4675
# Batch 2738/2908 | TrainLoss: 3.9582 | TrainAcc: 0.4410 | ValLoss: 3.7578 | ValAcc: 0.4678
# Batch 2739/2908 | TrainLoss: 3.8152 | TrainAcc: 0.4669 | ValLoss: 3.7545 | ValAcc: 0.4684
# Batch 2740/2908 | TrainLoss: 3.5667 | TrainAcc: 0.4873 | ValLoss: 3.7525 | ValAcc: 0.4685
# Batch 2741/2908 | TrainLoss: 3.9024 | TrainAcc: 0.4539 | ValLoss: 3.7530 | ValAcc: 0.4682
# Batch 2742/2908 | TrainLoss: 3.9489 | TrainAcc: 0.4417 | ValLoss: 3.7543 | ValAcc: 0.4679
# Batch 2743/2908 | TrainLoss: 4.1679 | TrainAcc: 0.4340 | ValLoss: 3.7567 | ValAcc: 0.4673
# Batch 2744/2908 | TrainLoss: 3.9625 | TrainAcc: 0.4364 | ValLoss: 3.7564 | ValAcc: 0.4672
# Batch 2745/2908 | TrainLoss: 3.5766 | TrainAcc: 0.4778 | ValLoss: 3.7542 | ValAcc: 0.4677
# Batch 2746/2908 | TrainLoss: 3.8445 | TrainAcc: 0.4628 | ValLoss: 3.7510 | ValAcc: 0.4683
# Batch 2747/2908 | TrainLoss: 3.7575 | TrainAcc: 0.4767 | ValLoss: 3.7497 | ValAcc: 0.4685
# Batch 2748/2908 | TrainLoss: 4.2021 | TrainAcc: 0.4301 | ValLoss: 3.7494 | ValAcc: 0.4686
# Batch 2749/2908 | TrainLoss: 3.9508 | TrainAcc: 0.4349 | ValLoss: 3.7495 | ValAcc: 0.4685
# Batch 2750/2908 | TrainLoss: 3.7562 | TrainAcc: 0.4736 | ValLoss: 3.7494 | ValAcc: 0.4684
# Batch 2751/2908 | TrainLoss: 3.9411 | TrainAcc: 0.4537 | ValLoss: 3.7495 | ValAcc: 0.4682
# Batch 2752/2908 | TrainLoss: 3.6928 | TrainAcc: 0.4477 | ValLoss: 3.7485 | ValAcc: 0.4685
# Batch 2753/2908 | TrainLoss: 3.8283 | TrainAcc: 0.4763 | ValLoss: 3.7473 | ValAcc: 0.4687
# Batch 2754/2908 | TrainLoss: 3.9078 | TrainAcc: 0.4481 | ValLoss: 3.7471 | ValAcc: 0.4686
# Batch 2755/2908 | TrainLoss: 3.7672 | TrainAcc: 0.4728 | ValLoss: 3.7476 | ValAcc: 0.4685
# Batch 2756/2908 | TrainLoss: 4.0329 | TrainAcc: 0.4292 | ValLoss: 3.7475 | ValAcc: 0.4686
# Batch 2757/2908 | TrainLoss: 3.6078 | TrainAcc: 0.4916 | ValLoss: 3.7473 | ValAcc: 0.4687
# Batch 2758/2908 | TrainLoss: 4.0206 | TrainAcc: 0.4390 | ValLoss: 3.7456 | ValAcc: 0.4691
# Batch 2759/2908 | TrainLoss: 3.7029 | TrainAcc: 0.4569 | ValLoss: 3.7454 | ValAcc: 0.4692
# Batch 2760/2908 | TrainLoss: 3.8467 | TrainAcc: 0.4681 | ValLoss: 3.7448 | ValAcc: 0.4692
# Batch 2761/2908 | TrainLoss: 3.7058 | TrainAcc: 0.4603 | ValLoss: 3.7442 | ValAcc: 0.4694
# Batch 2762/2908 | TrainLoss: 3.9582 | TrainAcc: 0.4373 | ValLoss: 3.7438 | ValAcc: 0.4695
# Batch 2763/2908 | TrainLoss: 3.9707 | TrainAcc: 0.4494 | ValLoss: 3.7426 | ValAcc: 0.4696
# Batch 2764/2908 | TrainLoss: 4.0499 | TrainAcc: 0.4574 | ValLoss: 3.7418 | ValAcc: 0.4693
# Batch 2765/2908 | TrainLoss: 3.9804 | TrainAcc: 0.4679 | ValLoss: 3.7422 | ValAcc: 0.4692
# Batch 2766/2908 | TrainLoss: 3.7465 | TrainAcc: 0.4483 | ValLoss: 3.7421 | ValAcc: 0.4690
# Batch 2767/2908 | TrainLoss: 3.7165 | TrainAcc: 0.4723 | ValLoss: 3.7415 | ValAcc: 0.4689
# Batch 2768/2908 | TrainLoss: 3.9330 | TrainAcc: 0.4567 | ValLoss: 3.7409 | ValAcc: 0.4688
# Batch 2769/2908 | TrainLoss: 3.6260 | TrainAcc: 0.4757 | ValLoss: 3.7406 | ValAcc: 0.4687
# Batch 2770/2908 | TrainLoss: 4.0003 | TrainAcc: 0.4413 | ValLoss: 3.7405 | ValAcc: 0.4687
# Batch 2771/2908 | TrainLoss: 3.5989 | TrainAcc: 0.4969 | ValLoss: 3.7400 | ValAcc: 0.4687
# Batch 2772/2908 | TrainLoss: 3.9214 | TrainAcc: 0.4261 | ValLoss: 3.7390 | ValAcc: 0.4688
# Batch 2773/2908 | TrainLoss: 3.5474 | TrainAcc: 0.4767 | ValLoss: 3.7382 | ValAcc: 0.4689
# Batch 2774/2908 | TrainLoss: 3.8232 | TrainAcc: 0.4743 | ValLoss: 3.7373 | ValAcc: 0.4693
# Batch 2775/2908 | TrainLoss: 4.1287 | TrainAcc: 0.4320 | ValLoss: 3.7363 | ValAcc: 0.4696
# Batch 2776/2908 | TrainLoss: 3.7795 | TrainAcc: 0.4436 | ValLoss: 3.7364 | ValAcc: 0.4696
# Batch 2777/2908 | TrainLoss: 3.7559 | TrainAcc: 0.4487 | ValLoss: 3.7359 | ValAcc: 0.4697
# Batch 2778/2908 | TrainLoss: 3.7834 | TrainAcc: 0.4650 | ValLoss: 3.7346 | ValAcc: 0.4699
# Batch 2779/2908 | TrainLoss: 4.1097 | TrainAcc: 0.4428 | ValLoss: 3.7337 | ValAcc: 0.4700
# Batch 2780/2908 | TrainLoss: 4.0203 | TrainAcc: 0.4408 | ValLoss: 3.7332 | ValAcc: 0.4700
# Batch 2781/2908 | TrainLoss: 4.2158 | TrainAcc: 0.4397 | ValLoss: 3.7334 | ValAcc: 0.4699
# Batch 2782/2908 | TrainLoss: 4.1686 | TrainAcc: 0.4232 | ValLoss: 3.7334 | ValAcc: 0.4700
# Batch 2783/2908 | TrainLoss: 3.7898 | TrainAcc: 0.4724 | ValLoss: 3.7335 | ValAcc: 0.4699
# Batch 2784/2908 | TrainLoss: 3.7680 | TrainAcc: 0.4637 | ValLoss: 3.7340 | ValAcc: 0.4697
# Batch 2785/2908 | TrainLoss: 3.8378 | TrainAcc: 0.4651 | ValLoss: 3.7338 | ValAcc: 0.4696
# Batch 2786/2908 | TrainLoss: 3.6057 | TrainAcc: 0.4589 | ValLoss: 3.7336 | ValAcc: 0.4696
# Batch 2787/2908 | TrainLoss: 3.8605 | TrainAcc: 0.4803 | ValLoss: 3.7339 | ValAcc: 0.4694
# Batch 2788/2908 | TrainLoss: 3.7368 | TrainAcc: 0.4858 | ValLoss: 3.7341 | ValAcc: 0.4695
# Batch 2789/2908 | TrainLoss: 3.9270 | TrainAcc: 0.4578 | ValLoss: 3.7332 | ValAcc: 0.4698
# Batch 2790/2908 | TrainLoss: 3.8066 | TrainAcc: 0.4581 | ValLoss: 3.7320 | ValAcc: 0.4697
# Batch 2791/2908 | TrainLoss: 3.8262 | TrainAcc: 0.4441 | ValLoss: 3.7305 | ValAcc: 0.4699
# Batch 2792/2908 | TrainLoss: 3.9610 | TrainAcc: 0.4407 | ValLoss: 3.7288 | ValAcc: 0.4702
# Batch 2793/2908 | TrainLoss: 3.8076 | TrainAcc: 0.4725 | ValLoss: 3.7276 | ValAcc: 0.4704
# Batch 2794/2908 | TrainLoss: 3.9541 | TrainAcc: 0.4716 | ValLoss: 3.7267 | ValAcc: 0.4705
# Batch 2795/2908 | TrainLoss: 3.9622 | TrainAcc: 0.4479 | ValLoss: 3.7263 | ValAcc: 0.4702
# Batch 2796/2908 | TrainLoss: 3.7599 | TrainAcc: 0.4837 | ValLoss: 3.7262 | ValAcc: 0.4700
# Batch 2797/2908 | TrainLoss: 3.9138 | TrainAcc: 0.4750 | ValLoss: 3.7263 | ValAcc: 0.4698
# Batch 2798/2908 | TrainLoss: 3.8780 | TrainAcc: 0.4197 | ValLoss: 3.7273 | ValAcc: 0.4694
# Batch 2799/2908 | TrainLoss: 3.8207 | TrainAcc: 0.4741 | ValLoss: 3.7288 | ValAcc: 0.4692
# Batch 2800/2908 | TrainLoss: 4.0296 | TrainAcc: 0.4389 | ValLoss: 3.7305 | ValAcc: 0.4690
# Batch 2801/2908 | TrainLoss: 4.0054 | TrainAcc: 0.4297 | ValLoss: 3.7309 | ValAcc: 0.4688
# Batch 2802/2908 | TrainLoss: 3.6400 | TrainAcc: 0.4628 | ValLoss: 3.7301 | ValAcc: 0.4689
# Batch 2803/2908 | TrainLoss: 4.1430 | TrainAcc: 0.4343 | ValLoss: 3.7290 | ValAcc: 0.4691
# Batch 2804/2908 | TrainLoss: 4.0279 | TrainAcc: 0.4281 | ValLoss: 3.7278 | ValAcc: 0.4696
# Batch 2805/2908 | TrainLoss: 3.6838 | TrainAcc: 0.4764 | ValLoss: 3.7269 | ValAcc: 0.4697
# Batch 2806/2908 | TrainLoss: 3.6760 | TrainAcc: 0.4673 | ValLoss: 3.7259 | ValAcc: 0.4700
# Batch 2807/2908 | TrainLoss: 3.7233 | TrainAcc: 0.4839 | ValLoss: 3.7248 | ValAcc: 0.4701
# Batch 2808/2908 | TrainLoss: 3.8469 | TrainAcc: 0.4705 | ValLoss: 3.7241 | ValAcc: 0.4705
# Batch 2809/2908 | TrainLoss: 3.7437 | TrainAcc: 0.4691 | ValLoss: 3.7246 | ValAcc: 0.4705
# Batch 2810/2908 | TrainLoss: 3.9787 | TrainAcc: 0.4429 | ValLoss: 3.7245 | ValAcc: 0.4707
# Batch 2811/2908 | TrainLoss: 3.9318 | TrainAcc: 0.4598 | ValLoss: 3.7233 | ValAcc: 0.4710
# Batch 2812/2908 | TrainLoss: 4.0178 | TrainAcc: 0.4165 | ValLoss: 3.7223 | ValAcc: 0.4714
# Batch 2813/2908 | TrainLoss: 3.6999 | TrainAcc: 0.4517 | ValLoss: 3.7210 | ValAcc: 0.4718
# Batch 2814/2908 | TrainLoss: 4.1157 | TrainAcc: 0.4535 | ValLoss: 3.7206 | ValAcc: 0.4718
# Batch 2815/2908 | TrainLoss: 3.7724 | TrainAcc: 0.4810 | ValLoss: 3.7206 | ValAcc: 0.4718
# Batch 2816/2908 | TrainLoss: 4.0753 | TrainAcc: 0.4315 | ValLoss: 3.7207 | ValAcc: 0.4716
# Batch 2817/2908 | TrainLoss: 3.8207 | TrainAcc: 0.4755 | ValLoss: 3.7202 | ValAcc: 0.4711
# Batch 2818/2908 | TrainLoss: 3.9942 | TrainAcc: 0.4483 | ValLoss: 3.7200 | ValAcc: 0.4707
# Batch 2819/2908 | TrainLoss: 4.0079 | TrainAcc: 0.4494 | ValLoss: 3.7208 | ValAcc: 0.4702
# Batch 2820/2908 | TrainLoss: 4.0294 | TrainAcc: 0.4466 | ValLoss: 3.7239 | ValAcc: 0.4697
# Batch 2821/2908 | TrainLoss: 4.0140 | TrainAcc: 0.4479 | ValLoss: 3.7266 | ValAcc: 0.4693
# Batch 2822/2908 | TrainLoss: 3.8583 | TrainAcc: 0.4733 | ValLoss: 3.7275 | ValAcc: 0.4691
# Batch 2823/2908 | TrainLoss: 3.7535 | TrainAcc: 0.4775 | ValLoss: 3.7263 | ValAcc: 0.4694
# Batch 2824/2908 | TrainLoss: 3.7464 | TrainAcc: 0.4808 | ValLoss: 3.7233 | ValAcc: 0.4697
# Batch 2825/2908 | TrainLoss: 3.7115 | TrainAcc: 0.4590 | ValLoss: 3.7208 | ValAcc: 0.4701
# Batch 2826/2908 | TrainLoss: 3.8926 | TrainAcc: 0.4195 | ValLoss: 3.7185 | ValAcc: 0.4706
# Batch 2827/2908 | TrainLoss: 3.6138 | TrainAcc: 0.4726 | ValLoss: 3.7164 | ValAcc: 0.4709
# Batch 2828/2908 | TrainLoss: 3.8161 | TrainAcc: 0.4561 | ValLoss: 3.7141 | ValAcc: 0.4713
# Batch 2829/2908 | TrainLoss: 3.6732 | TrainAcc: 0.4826 | ValLoss: 3.7118 | ValAcc: 0.4716
# Batch 2830/2908 | TrainLoss: 3.7921 | TrainAcc: 0.4704 | ValLoss: 3.7106 | ValAcc: 0.4719
# Batch 2831/2908 | TrainLoss: 3.9932 | TrainAcc: 0.4490 | ValLoss: 3.7103 | ValAcc: 0.4720
# Batch 2832/2908 | TrainLoss: 3.8064 | TrainAcc: 0.4305 | ValLoss: 3.7107 | ValAcc: 0.4719
# Batch 2833/2908 | TrainLoss: 4.1427 | TrainAcc: 0.4220 | ValLoss: 3.7109 | ValAcc: 0.4719
# Batch 2834/2908 | TrainLoss: 3.8305 | TrainAcc: 0.4666 | ValLoss: 3.7111 | ValAcc: 0.4718
# Batch 2835/2908 | TrainLoss: 3.8314 | TrainAcc: 0.4620 | ValLoss: 3.7112 | ValAcc: 0.4717
# Batch 2836/2908 | TrainLoss: 4.0061 | TrainAcc: 0.4361 | ValLoss: 3.7113 | ValAcc: 0.4716
# Batch 2837/2908 | TrainLoss: 3.9582 | TrainAcc: 0.4228 | ValLoss: 3.7117 | ValAcc: 0.4714
# Batch 2838/2908 | TrainLoss: 3.9378 | TrainAcc: 0.4395 | ValLoss: 3.7115 | ValAcc: 0.4713
# Batch 2839/2908 | TrainLoss: 3.7451 | TrainAcc: 0.4896 | ValLoss: 3.7124 | ValAcc: 0.4710
# Batch 2840/2908 | TrainLoss: 3.6567 | TrainAcc: 0.4935 | ValLoss: 3.7130 | ValAcc: 0.4710
# Batch 2841/2908 | TrainLoss: 3.9086 | TrainAcc: 0.4382 | ValLoss: 3.7122 | ValAcc: 0.4712
# Batch 2842/2908 | TrainLoss: 3.6459 | TrainAcc: 0.4784 | ValLoss: 3.7098 | ValAcc: 0.4714
# Batch 2843/2908 | TrainLoss: 3.6490 | TrainAcc: 0.4538 | ValLoss: 3.7081 | ValAcc: 0.4715
# Batch 2844/2908 | TrainLoss: 3.6661 | TrainAcc: 0.4831 | ValLoss: 3.7072 | ValAcc: 0.4716
# Batch 2845/2908 | TrainLoss: 3.8309 | TrainAcc: 0.4493 | ValLoss: 3.7070 | ValAcc: 0.4717
# Batch 2846/2908 | TrainLoss: 3.9114 | TrainAcc: 0.4341 | ValLoss: 3.7064 | ValAcc: 0.4719
# Batch 2847/2908 | TrainLoss: 3.8164 | TrainAcc: 0.4612 | ValLoss: 3.7061 | ValAcc: 0.4719
# Batch 2848/2908 | TrainLoss: 3.7144 | TrainAcc: 0.4811 | ValLoss: 3.7054 | ValAcc: 0.4721
# Batch 2849/2908 | TrainLoss: 3.6069 | TrainAcc: 0.4890 | ValLoss: 3.7059 | ValAcc: 0.4719
# Batch 2850/2908 | TrainLoss: 3.6106 | TrainAcc: 0.4875 | ValLoss: 3.7068 | ValAcc: 0.4718
# Batch 2851/2908 | TrainLoss: 4.0125 | TrainAcc: 0.4483 | ValLoss: 3.7071 | ValAcc: 0.4717
# Batch 2852/2908 | TrainLoss: 3.8443 | TrainAcc: 0.4388 | ValLoss: 3.7064 | ValAcc: 0.4717
# Batch 2853/2908 | TrainLoss: 4.0019 | TrainAcc: 0.4521 | ValLoss: 3.7054 | ValAcc: 0.4718
# Batch 2854/2908 | TrainLoss: 3.9050 | TrainAcc: 0.4477 | ValLoss: 3.7039 | ValAcc: 0.4718
# Batch 2855/2908 | TrainLoss: 3.6432 | TrainAcc: 0.4750 | ValLoss: 3.7035 | ValAcc: 0.4717
# Batch 2856/2908 | TrainLoss: 3.8383 | TrainAcc: 0.4358 | ValLoss: 3.7039 | ValAcc: 0.4715
# Batch 2857/2908 | TrainLoss: 3.9134 | TrainAcc: 0.4506 | ValLoss: 3.7038 | ValAcc: 0.4713
# Batch 2858/2908 | TrainLoss: 3.7145 | TrainAcc: 0.4609 | ValLoss: 3.7041 | ValAcc: 0.4712
# Batch 2859/2908 | TrainLoss: 3.8185 | TrainAcc: 0.4734 | ValLoss: 3.7034 | ValAcc: 0.4711
# Batch 2860/2908 | TrainLoss: 3.8171 | TrainAcc: 0.4437 | ValLoss: 3.7021 | ValAcc: 0.4712
# Batch 2861/2908 | TrainLoss: 3.5711 | TrainAcc: 0.4714 | ValLoss: 3.7007 | ValAcc: 0.4714
# Batch 2862/2908 | TrainLoss: 3.8047 | TrainAcc: 0.4528 | ValLoss: 3.7000 | ValAcc: 0.4714
# Batch 2863/2908 | TrainLoss: 4.1461 | TrainAcc: 0.4411 | ValLoss: 3.6997 | ValAcc: 0.4716
# Batch 2864/2908 | TrainLoss: 3.8321 | TrainAcc: 0.4505 | ValLoss: 3.6999 | ValAcc: 0.4716
# Batch 2865/2908 | TrainLoss: 3.9878 | TrainAcc: 0.4324 | ValLoss: 3.7003 | ValAcc: 0.4715
# Batch 2866/2908 | TrainLoss: 3.8993 | TrainAcc: 0.4699 | ValLoss: 3.6999 | ValAcc: 0.4716
# Batch 2867/2908 | TrainLoss: 3.9068 | TrainAcc: 0.4535 | ValLoss: 3.6985 | ValAcc: 0.4717
# Batch 2868/2908 | TrainLoss: 3.7711 | TrainAcc: 0.4883 | ValLoss: 3.6981 | ValAcc: 0.4717
# Batch 2869/2908 | TrainLoss: 3.8828 | TrainAcc: 0.4537 | ValLoss: 3.6969 | ValAcc: 0.4722
# Batch 2870/2908 | TrainLoss: 3.7019 | TrainAcc: 0.4605 | ValLoss: 3.6958 | ValAcc: 0.4725
# Batch 2871/2908 | TrainLoss: 3.8387 | TrainAcc: 0.4519 | ValLoss: 3.6951 | ValAcc: 0.4727
# Batch 2872/2908 | TrainLoss: 3.8505 | TrainAcc: 0.4735 | ValLoss: 3.6947 | ValAcc: 0.4726
# Batch 2873/2908 | TrainLoss: 3.8592 | TrainAcc: 0.4547 | ValLoss: 3.6952 | ValAcc: 0.4726
# Batch 2874/2908 | TrainLoss: 3.8644 | TrainAcc: 0.4425 | ValLoss: 3.6954 | ValAcc: 0.4726
# Batch 2875/2908 | TrainLoss: 3.4664 | TrainAcc: 0.5204 | ValLoss: 3.6959 | ValAcc: 0.4724
# Batch 2876/2908 | TrainLoss: 3.6360 | TrainAcc: 0.4633 | ValLoss: 3.6954 | ValAcc: 0.4724
# Batch 2877/2908 | TrainLoss: 3.9130 | TrainAcc: 0.4544 | ValLoss: 3.6944 | ValAcc: 0.4726
# Batch 2878/2908 | TrainLoss: 3.7670 | TrainAcc: 0.4711 | ValLoss: 3.6928 | ValAcc: 0.4728
# Batch 2879/2908 | TrainLoss: 3.8086 | TrainAcc: 0.4542 | ValLoss: 3.6916 | ValAcc: 0.4730
# Batch 2880/2908 | TrainLoss: 3.9812 | TrainAcc: 0.4507 | ValLoss: 3.6913 | ValAcc: 0.4730
# Batch 2881/2908 | TrainLoss: 4.0152 | TrainAcc: 0.4545 | ValLoss: 3.6910 | ValAcc: 0.4730
# Batch 2882/2908 | TrainLoss: 3.5749 | TrainAcc: 0.4903 | ValLoss: 3.6903 | ValAcc: 0.4730
# Batch 2883/2908 | TrainLoss: 3.7734 | TrainAcc: 0.4529 | ValLoss: 3.6889 | ValAcc: 0.4730
# Batch 2884/2908 | TrainLoss: 3.9751 | TrainAcc: 0.4375 | ValLoss: 3.6878 | ValAcc: 0.4731
# Batch 2885/2908 | TrainLoss: 3.5493 | TrainAcc: 0.4864 | ValLoss: 3.6869 | ValAcc: 0.4731
# Batch 2886/2908 | TrainLoss: 4.0452 | TrainAcc: 0.4295 | ValLoss: 3.6864 | ValAcc: 0.4731
# Batch 2887/2908 | TrainLoss: 3.8000 | TrainAcc: 0.4834 | ValLoss: 3.6854 | ValAcc: 0.4733
# Batch 2888/2908 | TrainLoss: 3.8777 | TrainAcc: 0.4522 | ValLoss: 3.6848 | ValAcc: 0.4735
# Batch 2889/2908 | TrainLoss: 3.5068 | TrainAcc: 0.4898 | ValLoss: 3.6855 | ValAcc: 0.4735
# Batch 2890/2908 | TrainLoss: 3.7812 | TrainAcc: 0.4634 | ValLoss: 3.6880 | ValAcc: 0.4731
# Batch 2891/2908 | TrainLoss: 3.8742 | TrainAcc: 0.4600 | ValLoss: 3.6909 | ValAcc: 0.4726
# Batch 2892/2908 | TrainLoss: 3.7603 | TrainAcc: 0.4518 | ValLoss: 3.6913 | ValAcc: 0.4726
# Batch 2893/2908 | TrainLoss: 3.8303 | TrainAcc: 0.4539 | ValLoss: 3.6913 | ValAcc: 0.4726
# Batch 2894/2908 | TrainLoss: 3.6652 | TrainAcc: 0.4832 | ValLoss: 3.6890 | ValAcc: 0.4730
# Batch 2895/2908 | TrainLoss: 3.7304 | TrainAcc: 0.4730 | ValLoss: 3.6868 | ValAcc: 0.4735
# Batch 2896/2908 | TrainLoss: 3.9844 | TrainAcc: 0.4526 | ValLoss: 3.6857 | ValAcc: 0.4736
# Batch 2897/2908 | TrainLoss: 3.6600 | TrainAcc: 0.4629 | ValLoss: 3.6868 | ValAcc: 0.4737
# Batch 2898/2908 | TrainLoss: 3.7636 | TrainAcc: 0.4648 | ValLoss: 3.6879 | ValAcc: 0.4734
# Batch 2899/2908 | TrainLoss: 3.7729 | TrainAcc: 0.4639 | ValLoss: 3.6876 | ValAcc: 0.4736
# Batch 2900/2908 | TrainLoss: 3.7914 | TrainAcc: 0.4515 | ValLoss: 3.6853 | ValAcc: 0.4740
# Batch 2901/2908 | TrainLoss: 3.9014 | TrainAcc: 0.4416 | ValLoss: 3.6823 | ValAcc: 0.4745
# Batch 2902/2908 | TrainLoss: 3.7148 | TrainAcc: 0.4800 | ValLoss: 3.6800 | ValAcc: 0.4749
# Batch 2903/2908 | TrainLoss: 3.7550 | TrainAcc: 0.4554 | ValLoss: 3.6793 | ValAcc: 0.4749
# Batch 2904/2908 | TrainLoss: 3.7434 | TrainAcc: 0.4649 | ValLoss: 3.6799 | ValAcc: 0.4747
# Batch 2905/2908 | TrainLoss: 3.8818 | TrainAcc: 0.4857 | ValLoss: 3.6804 | ValAcc: 0.4744
# Batch 2906/2908 | TrainLoss: 3.7861 | TrainAcc: 0.4610 | ValLoss: 3.6805 | ValAcc: 0.4743
# Batch 2907/2908 | TrainLoss: 3.7161 | TrainAcc: 0.4543 | ValLoss: 3.6810 | ValAcc: 0.4740
# Batch 2908/2908 | TrainLoss: 3.4064 | TrainAcc: 0.4444 | ValLoss: 3.6827 | ValAcc: 0.4737
#
# Final Test Loss: 3.6951 | Final Test Accuracy: 0.4713
#
# --- Translation Examples ---
# English: Hello, how are you?
# Russian: <unk> как ты <unk>
#
# English: I love programming and coffee.
# Russian: я люблю <unk> и <unk> <unk>
#
# English: This is a simple test.
# Russian: это <unk> <unk> <unk>
